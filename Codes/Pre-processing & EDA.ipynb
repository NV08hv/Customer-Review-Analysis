# %% [markdown]
# Nguồn dữ liệu: https://www.kaggle.com/datasets/rishidamarla/amazoncom-fashion-products/data

# %% [markdown]
# ## Cài đặt thư viện

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
# !pip install kmodes
# Out:
# Collecting kmodes
#   Downloading kmodes-0.12.2-py2.py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.11/dist-packages (from kmodes) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from kmodes) (1.6.1)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.11/dist-packages (from kmodes) (1.13.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from kmodes) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.0->kmodes) (3.5.0)
# Downloading kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# Installing collected packages: kmodes
# Successfully installed kmodes-0.12.2

# %%
import re
import ast
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from wordcloud import WordCloud, STOPWORDS
from sklearn.preprocessing import LabelEncoder
from kmodes.kprototypes import KPrototypes
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %% [markdown]
# ## Đọc dữ liệu

# %%
df = pd.read_csv('/content/drive/MyDrive/Course DA/Final Project/amazon_co-ecommerce_sample.csv')
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                       NaN                 2                           1.0
# 2                     2 new                17                           2.0
# 3                       NaN                 1                           2.0
# 4                       NaN                 3                           2.0
#
#   average_review_rating                   amazon_category_and_sub_category  \
# 0    4.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 1    4.5 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 2    3.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 3    5.0 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 4    4.7 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
#
#           customers_who_bought_this_item_also_bought  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                                                NaN
# 4  http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
#
#                                          description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
# 1  Technical Details Manufacturer recommended age...
# 2  Technical Details Manufacturer recommended age...
# 3  Technical Details Item Weight259 g Product Dim...
# 4  Technical Details Item Weight159 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                                NaN
# 4  http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
# 1  can you turn off sounds // hi no you cant turn...
# 2  What is the gauge of the track // Hi Paul.Trut...
# 3                                                NaN
# 4                                                NaN
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3  I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4  Birthday present // 5.0 // 14 April 2014 // By...
#
#                                              sellers
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ## Bước 1: Tạo từ điển dữ liệu và đánh giá chất lượng dữ liệu

# %% [markdown]
# ### Thông tin về dữ liệu

# %%
print('Số dòng: ', df.shape[0])
print('Số cột: ', df.shape[1])
# Out:
# Number of rows:  10000
# Number of columns:  17

# %%
df.dtypes
# Out:
# uniq_id                                         object
# product_name                                    object
# manufacturer                                    object
# price                                           object
# number_available_in_stock                       object
# number_of_reviews                               object
# number_of_answered_questions                   float64
# average_review_rating                           object
# amazon_category_and_sub_category                object
# customers_who_bought_this_item_also_bought      object
# description                                     object
# product_information                             object
# product_description                             object
# items_customers_buy_after_viewing_this_item     object
# customer_questions_and_answers                  object
# customer_reviews                                object
# sellers                                         object
# dtype: object

# %%
numerics_df = df.select_dtypes(include = np.number)
variable_df = df.select_dtypes(include = 'object')
print('Cột dữ liệu số: ',numerics_df.columns)
print('Cột dữ liệu phân loại: ', variable_df.columns)
# Out:
# digital data columns:  Index(['number_of_answered_questions'], dtype='object')
# category data:  Index(['uniq_id', 'product_name', 'manufacturer', 'price',
#        'number_available_in_stock', 'number_of_reviews',
#        'average_review_rating', 'amazon_category_and_sub_category',
#        'customers_who_bought_this_item_also_bought', 'description',
#        'product_information', 'product_description',
#        'items_customers_buy_after_viewing_this_item',
#        'customer_questions_and_answers', 'customer_reviews', 'sellers'],
#       dtype='object')

# %%
for column in variable_df.columns:
    unique = variable_df[column].unique()
    print(f"Gía trị duy nhất của cột {column}: {unique}")
    print("-----------------------------------")
# Out:
# Unique value of uniq_id: ['eac7efa5dbd3d667f26eb3d3ab504464' 'b17540ef7e86e461d37f3ae58b7b72ac'
#  '348f344247b0c1a935b1223072ef9d8a' ... 'bf6cc073f8f24e6e338190fa16f6ee9d'
#  'cd783d0b8b44e631b9788b203eaaefae' '94d18e86e504bee1e392df7e5738b18a']
# -----------------------------------
# Unique value of product_name: ['Hornby 2014 Catalogue'
#  'FunkyBuys® Large Christmas Holiday Express Festive Train Set (SI-TY1017) Toy Light / Sounds / Battery Operated & Smoke'
#  'CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT ENGINE BOXED BOYS KIDS BATTERY'
#  ... 'Defiance Lawkeeper Metal Badge Prop Replica'
#  'Justice League of America Series 3 Green Lantern Action Figure'
#  'Star Wars 1/72 Y-Wing Starfighter']
# -----------------------------------
# Unique value of manufacturer: ['Hornby' 'FunkyBuys' 'ccf' ... 'Captain america' 'IronMan' 'Super Heroes']
# -----------------------------------
# Unique value of price: ['£3.42' '£16.99' '£9.99' ... '£29.79' '£49.81' '£21.20']
# -----------------------------------
# Unique value of number_available_in_stock: ['5\xa0new' nan '2\xa0new' '3\xa0new' '4\xa0new' '1\xa0new' '6\xa0new'
#  '18\xa0new' '12\xa0new' '1\xa0used' '26\xa0new' '37\xa0new' '35\xa0new'
#  '22\xa0new' '11\xa0new' '16\xa0new' '31\xa0new' '9\xa0new' '29\xa0new'
#  '33\xa0new' '7\xa0new' '15\xa0new' '13\xa0new' '19\xa0new' '27\xa0new'
#  '10\xa0new' '39\xa0new' '23\xa0new' '38\xa0new' '8\xa0new' '17\xa0new'
#  '34\xa0new' '30\xa0new' '21\xa0new' '14\xa0new' '32\xa0new' '3\xa0used'
#  '20\xa0new' '43\xa0new' '25\xa0new' '24\xa0new' '8\xa0used' '7\xa0used'
#  '41\xa0new' '47\xa0new' '73\xa0new' '58\xa0new' '49\xa0new' '36\xa0new'
#  '72\xa0new' '1\xa0collectible' '40\xa0new' '1\xa0refurbished' '28\xa0new'
#  '2\xa0used' '6\xa0used' '69\xa0new' '44\xa0new' '55\xa0new' '56\xa0new'
#  '52\xa0new' '71\xa0new' '86\xa0new' '60\xa0new' '92\xa0new' '65\xa0new'
#  '74\xa0new' '50\xa0new' '63\xa0new' '78\xa0new' '4\xa0used' '51\xa0new'
#  '53\xa0new' '64\xa0new' '48\xa0new' '57\xa0new' '42\xa0new' '46\xa0new'
#  '14\xa0used' '5\xa0used' '2\xa0collectible' '54\xa0new' '59\xa0new'
#  '66\xa0new' '45\xa0new' '62\xa0new' '70\xa0new' '10\xa0used' '12\xa0used'
#  '9\xa0used']
# -----------------------------------
# Unique value of number_of_reviews: ['15' '2' '17' '1' '3' '36' '8' '21' '4' '5' '19' '53' '6' '38' '10' '7'
#  nan '9' '13' '18' '97' '28' '12' '67' '81' '23' '41' '11' '16' '45' '42'
#  '32' '27' '40' '31' '35' '29' '120' '33' '26' '24' '85' '25' '43' '138'
#  '82' '46' '14' '72' '22' '106' '76' '420' '160' '39' '30' '199' '129'
#  '56' '291' '87' '86' '20' '34' '142' '92' '55' '64' '77' '243' '130' '68'
#  '253' '101' '102' '122' '73' '118' '145' '381' '802' '299' '59' '518'
#  '158' '44' '98' '58' '47' '600' '57' '50' '78' '94' '51' '37' '210' '165'
#  '103' '185' '116' '149' '168' '71' '649' '265' '355' '79' '100' '83' '61'
#  '48' '70' '65' '49' '54' '66' '60' '238' '133' '88' '110' '117' '109'
#  '127' '63' '111' '141' '99' '204' '124' '95' '220' '137' '90' '172' '134'
#  '115' '80' '91' '125' '119' '131' '146' '517' '512' '151' '62' '113'
#  '104' '108' '126' '75' '107' '183' '313' '139' '230' '93' '181' '114'
#  '52' '74' '96' '561' '144' '147' '128' '136' '105' '585' '156' '155'
#  '516' '112' '200' '379' '177' '132' '69' '140' '1,040' '337' '164' '193'
#  '1,399' '690' '123' '263' '249' '287' '202' '304' '262' '241']
# -----------------------------------
# Unique value of average_review_rating: ['4.9 out of 5 stars' '4.5 out of 5 stars' '3.9 out of 5 stars'
#  '5.0 out of 5 stars' '4.7 out of 5 stars' '4.3 out of 5 stars'
#  '4.8 out of 5 stars' '4.0 out of 5 stars' '4.2 out of 5 stars'
#  '4.6 out of 5 stars' '4.1 out of 5 stars' nan '4.4 out of 5 stars'
#  '3.5 out of 5 stars' '3.0 out of 5 stars' '3.3 out of 5 stars'
#  '3.7 out of 5 stars' '3.8 out of 5 stars' '3.6 out of 5 stars'
#  '2.3 out of 5 stars']
# -----------------------------------
# Unique value of amazon_category_and_sub_category: ['Hobbies > Model Trains & Railway Sets > Rail Vehicles > Trains'
#  'Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Lamps & Lighting'
#  'Hobbies > Model Trains & Railway Sets > Rail Vehicles > Locomotives'
#  'Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Signal & Sound'
#  'Hobbies > Model Trains & Railway Sets > Accessories > Recreational Activities'
#  'Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Transformers & Decoders'
#  nan 'Characters & Brands > Thomas & Friends > Train Play > Wooden Thomas'
#  'Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Control Moduls'
#  'Hobbies > Model Trains & Railway Sets > Accessories > Landscaping'
#  'Characters & Brands > Thomas & Friends > Train Play > Motor Road & Rail'
#  'Characters & Brands > Hasbro' 'Characters & Brands > Star Wars > Toys'
#  'Characters & Brands > Disney > Toys' 'Fancy Dress > Costumes'
#  'Bags > Schoolbags & Backpacks > Bags'
#  "Arts & Crafts > Children's Craft Kits" 'Characters & Brands > Tomy'
#  "Handbags & Shoulder Bags > Kids'" 'Games > Dice & Dice Games'
#  'Games > Board Games' 'Arts & Crafts > Art Sand'
#  'Arts & Crafts > Felt Kits' 'Figures & Playsets > Farm & Animals'
#  'Characters & Brands > Barbie'
#  'Home Accessories > Decorative Accessories > Stickers > Window Stickers'
#  'Arts & Crafts > Art & Craft Supplies > Glitter'
#  'Figures & Playsets > Pirates'
#  'Figures & Playsets > Science Fiction & Fantasy'
#  'Figures & Playsets > Knights & Castles'
#  'Sweets, Chocolate & Gum > Chocolate'
#  'Sports Toys & Outdoor > Beach Toys > Beach Toys'
#  'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models > Vehicles'
#  'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models > Boats'
#  'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models > Trains'
#  'Baby & Toddler Toys > Pushchair Toys'
#  'Hobbies > Model Building Kits > Figures'
#  'Characters & Brands > Action Man'
#  'Characters & Brands > Toy Story > Toys'
#  'Hobbies > Collectible Figures & Memorabilia > Collectible Figures & Accessories'
#  'Hobbies > Collectible Figures & Memorabilia > Collectible Props & Memorabilia'
#  'Hobbies > Collectible Figures & Memorabilia > Bobbleheads & Busts'
#  'Characters & Brands > Harry Potter > Toys'
#  'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Rockets & Spaceships'
#  'Fancy Dress > Accessories'
#  "Arts & Crafts > Children's Craft Kits > Bead Art & Jewellery-Making"
#  "Arts & Crafts > Children's Chalk" 'Arts & Crafts > Blackboards'
#  'Storage, Cleaning & Ring Sizers > Boxes & Organisers'
#  "Bedding & Linens > Children's Bedding > Sheets & Pillowcases > Flat Sheets"
#  'Characters & Brands > Crayola' 'Arts & Crafts > Paper & Stickers'
#  'Arts & Crafts > Painting By Numbers'
#  'Characters & Brands > Early Learning Centre'
#  'Office Supplies > Labels, Index Dividers & Stamps > Labels & Stickers'
#  'Hobbies > Model Building Kits > Model Building Tools'
#  'Home Accessories > Seasonal Décor > Christmas'
#  'Party Supplies > Banners, Stickers & Confetti > Banners'
#  'Arts & Crafts > Doll Making'
#  'Sports Toys & Outdoor > Beach Toys > Airbeds & Inflating Devices'
#  'Sports Toys & Outdoor > Beach Toys > Water Pistols'
#  'Sports Toys & Outdoor > Beach Toys > Paddling Pools'
#  'Sports Toys & Outdoor > Beach Toys > Water Play Tables'
#  'Sports Toys & Outdoor > Beach Toys > Flotation Devices & Accessories'
#  'Camping & Hiking > Sleeping Gear > Air Pumps > Hand Pumps'
#  'Pretend Play > Play Tools' 'Fancy Dress > Accessories > Sets & Kits'
#  'Fancy Dress > Costumes > Adults'
#  'Fancy Dress > Costumes > Kids & Toddlers'
#  'Fancy Dress > Accessories > Temporary Tattoos' 'Women > Accessories'
#  'Hobbies > Slot Cars, Race Tracks & Accessories > Race Tracks'
#  'Hobbies > Remote Controlled Devices > Robots'
#  'Hobbies > Remote Controlled Devices > Tanks'
#  'Hobbies > Slot Cars, Race Tracks & Accessories'
#  'Electronic Toys > Robots'
#  'Hobbies > Slot Cars, Race Tracks & Accessories > Slot Cars'
#  'Hobbies > Slot Cars, Race Tracks & Accessories > Service & Tuning Parts'
#  'Hobbies > Remote Controlled Devices > Helicopters & Quadcopters'
#  'Hobbies > Remote Controlled Devices > Parts & Accessories'
#  'Electronic Toys > Kids Remote & App Controlled Toys'
#  'Hobbies > Model Building Kits > Accessories'
#  'Car Parts > Instruments > Nuts & Bolts'
#  'Hobbies > Trading Cards & Accessories > Packs & Sets'
#  'Hobbies > Model Building Kits'
#  'Hobbies > Model Building Kits > Boats & Watercraft'
#  'Baby & Toddler Toys > Spinning Tops' 'Party Supplies > Party Favours'
#  'Dolls & Accessories > Fashion Dolls & Accessories'
#  'Characters & Brands > Bob the Builder > Toys'
#  'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Friction Cars'
#  'Baby & Toddler Toys > Teaching Clocks'
#  'Indoor Lighting > Specialty & Decorative Lighting > Book Lights'
#  'Figures & Playsets > Cowboys & Indians'
#  'Figures & Playsets > Accessories'
#  'Games > Casino Equipment > Game Sets > Poker Sets'
#  'Characters & Brands > BRIO > BRIO Builder System'
#  'Figures & Playsets > Transportation & Traffic'
#  'Characters & Brands > Barbie > Barbie Dolls & Accessories'
#  'Educational Toys > Mathematics'
#  'Characters & Brands > BRIO > BRIO Wooden Railway System'
#  'Electronic Toys > Digital Cameras'
#  'Laundry, Storage & Organisation > Baskets & Bins > Storage Boxes & Chests > Storage Boxes'
#  "Supporters' Gear > Football > Memorabilia & Collectibles"
#  'Jams, Honey & Spreads > Sandwich Spreads, Pates & Pastes'
#  'Hobbies > Trading Cards & Accessories > Storage Albums & Cases > Albums'
#  'Games > Casino Equipment > Game Sets' 'Novelty & Special Use > Novelty'
#  "Characters & Brands > Upstarts > Children's Games"
#  'Sweets, Chocolate & Gum > Chocolate > Bars > Multipack Bars'
#  'Party Supplies > Decorations > Balloons'
#  'Party Supplies > Decorations > Props'
#  'Musical Toy Instruments > Guitars & Strings'
#  'Party Supplies > Banners, Stickers & Confetti > Streamers'
#  'Party Supplies > Decorations > Cake Decorations'
#  'Party Supplies > Invitations' 'Party Supplies > Party Tableware'
#  'Men > Tops & T-Shirts > T-Shirts'
#  "Sex & Sensuality > Erotic Clothing > Women's > Costumes"
#  'Novelty & Special Use > Novelty > Accessories > Buttons & Pins'
#  'Fancy Dress > Accessories > Capes & Wings'
#  'Fancy Dress > Accessories > Hats'
#  'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Toy Cars & Trucks'
#  'Hobbies > Model Building Kits > Tanks'
#  'Hobbies > Model Building Kits > Steam Engines'
#  'Hobbies > Model Trains & Railway Sets > Accessories'
#  'Hobbies > Model Trains & Railway Sets > Accessories > Landscaping > Landscape Architecture'
#  'Hobbies > Model Trains & Railway Sets > Accessories > Figures & Decoration Parts > Figures'
#  'Fancy Dress > Accessories > Masks'
#  'Women > Accessories > Eyewear & Accessories > Sunglasses'
#  'Figures & Playsets > Emergency Services'
#  'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models'
#  'Characters & Brands > Thunderbirds > Toys'
#  'Hobbies > Model Building Kits > Cars & Vehicles'
#  'Cooking & Dining > Kitchen Tools & Gadgets > Barware > Coasters'
#  'Hobbies > Model Trains & Railway Sets'
#  'Medication & Remedies > Alternative Medicine'
#  'Sports Toys & Outdoor > Bikes, Trikes & Ride-ons'
#  'Puppets & Puppet Theatres > Finger Puppets'
#  'Indoor Lighting > Specialty & Decorative Lighting'
#  'Baby & Toddler Toys > Activity Centres'
#  'Sports Toys & Outdoor > Bikes, Trikes & Ride-ons > Scooters'
#  'Medication & Remedies > Pain & Fever > Hot & Cold Therapies'
#  'Puppets & Puppet Theatres > Hand Puppets'
#  'Jigsaws & Puzzles > 3-D Puzzles'
#  'Hobbies > Trading Cards & Accessories > Storage Albums & Cases > Sleeves'
#  'Hobbies > Trading Cards & Accessories > Sticker Collections'
#  'Characters & Brands > Ravensburger' 'Jigsaws & Puzzles > Jigsaws'
#  'Hobbies > Trading Cards & Accessories > Storage Albums & Cases > Cases'
#  'Jigsaws & Puzzles > Brain Teasers' 'Jigsaws & Puzzles > Frame Jigsaws'
#  'Characters & Brands > Ravensburger > Games'
#  'Musical Toy Instruments > Pianos & Keyboards'
#  'Party Supplies > Banners, Stickers & Confetti > Garlands'
#  'Arts & Crafts > Art & Craft Supplies > Thread > Sewing'
#  'Party Supplies > Banners, Stickers & Confetti > Confetti'
#  'Games > Card Games'
#  'Hobbies > Trading Cards & Accessories > Single Cards'
#  'Games > Casino Equipment > Game Layouts > Poker Layouts'
#  'Hobbies > Trading Cards & Accessories'
#  "Characters & Brands > Marvin's Magic" 'Games > Chess'
#  'Games > Casino Equipment > Game Tables > Poker Tables'
#  'Games > Casino Equipment > Bingo Equipment'
#  'Games > Casino Equipment > Game Layouts > Craps Layouts'
#  'Games > Casino Equipment > Game Sets > Blackjack Sets'
#  'Games > Casino Equipment > Poker Chips'
#  'Games > Casino Equipment > Poker Chip Cases & Trays > Cases'
#  'Games > Casino Equipment > Game Sets > Roulette Sets'
#  'Characters & Brands > Harry Potter > Books > Stationery'
#  'Hobbies > Model Trains & Railway Sets > Accessories > Landscaping > Track Construction'
#  'Hobbies > Model Trains & Railway Sets > Accessories > Landscaping > Road Construction'
#  'Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Cable'
#  'Dogs > Clothing & Accessories > Costumes'
#  'Figures & Playsets > Dinosaurs'
#  'Characters & Brands > Winnie-the-Pooh > Toys'
#  'Characters & Brands > VTech'
#  'Medical Supplies & Equipment > Braces, Splints & Slings > Tape & Supplies'
#  'Cooking & Dining > Kitchen Tools & Gadgets > Barware > Ice Cube Moulds & Trays'
#  'Musical Toy Instruments > Wind & Brass'
#  'Characters & Brands > Action Man > Toys'
#  'Home Accessories > Seasonal Décor > Christmas > Novelty Decorations'
#  'Office Supplies > Desk Accessories & Storage Products > Desk Supplies Organisers & Dispensers > Desk Supplies Organisers'
#  'Arts & Crafts > Colouring Pens & Markers'
#  'Arts & Crafts > Colouring Pencils'
#  'Arts & Crafts > Drawing & Painting Supplies > Paints > Poster Paints'
#  'Pens, Pencils & Writing Supplies > Markers & Highlighters > Permanent Markers & Marker Pens'
#  'Pens, Pencils & Writing Supplies > Erasers & Correction Supplies > Erasers'
#  'Pens, Pencils & Writing Supplies > Pencils > Coloured Pencils'
#  'Pens, Pencils & Writing Supplies > Erasers & Correction Supplies > Correction Pens'
#  'Pens, Pencils & Writing Supplies > Pens & Refills > Pen Refills'
#  'Pens, Pencils & Writing Supplies > Markers & Highlighters > Art Markers'
#  'Baby & Toddler Toys > Sorting, Stacking & Plugging Toys'
#  'Baby & Toddler Toys > Sound Toys' 'Baby & Toddler Toys > Rocking Horses'
#  'Baby & Toddler Toys > Rattles'
#  'Baby & Toddler Toys > Learning & Activity Toys'
#  'Baby & Toddler Toys > Rockers & Ride-ons'
#  "Dolls & Accessories > Dolls' House Dolls & Accessories > Dolls' House Accessories"
#  'Die-Cast & Toy Vehicles > Toy Trains & Accessories > Toy Trains & Sets'
#  'Educational Toys > Literacy & Spelling'
#  'Games > Tabletop & Miniature Gaming' 'Characters & Brands > WWE'
#  'Figures & Playsets > Sport'
#  'Sports Toys & Outdoor > Kites & Flight Toys'
#  'Worlds Apart > Kid Venture > Kites'
#  'Sports Toys & Outdoor > Garden Tools'
#  'Sports Toys & Outdoor > Darts & Accessories'
#  'Sports Toys & Outdoor > Climbing Frames'
#  'Gardening > Hand Tools > Gardening Trowels'
#  'Sports Toys & Outdoor > Cup & Ball Games'
#  'Gardening > Greenhouses & Plant Germination Equipment > Greenhouses'
#  'Sports Toys & Outdoor > Target Games'
#  'Sports Toys & Outdoor > Racket Games'
#  "Characters & Brands > Ravensburger > Children's Puzzles"
#  'Jigsaws & Puzzles > Jigsaw Accessories'
#  'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models > Aircraft'
#  'Characters & Brands > BRIO > BRIO Wooden Roadway System'
#  'Hobbies > Model Trains & Railway Sets > Rail Vehicles > Wagons'
#  'Characters & Brands > Thomas & Friends > Ages 3-4 Years'
#  'Characters & Brands > Thomas & Friends > Train Play > Take Along Thomas'
#  'Hobbies > Model Trains & Railway Sets > Starter Packs & Sets'
#  'Lab & Scientific Products > Lab Instruments & Equipment > Microscopes & Equipment > Microscopes'
#  'Die-Cast & Toy Vehicles > Toy Vehicle Playsets'
#  'Party Supplies > Party Bags' 'Dolls & Accessories > Playsets'
#  'Dolls & Accessories > Fashion Dolls & Accessories > Vehicles'
#  'Dolls & Accessories > Fashion Dolls & Accessories > Houses'
#  'Dolls & Accessories > Soft Dolls'
#  "Sports Toys & Outdoor > Bikes, Trikes & Ride-ons > Children's Bikes"
#  'Games > Educational Games' 'Pretend Play > Shops & Accessories'
#  'Puppets & Puppet Theatres > Accessories'
#  "Dolls & Accessories > Dolls' House Dolls & Accessories > Dolls' House Furniture"
#  "Dolls & Accessories > Dolls' House Dolls & Accessories > Dolls' Houses"
#  'Figures & Playsets > Military' 'Games > Strategy Games'
#  'Characters & Brands > LeapFrog > LeapPad Learning System'
#  'Characters & Brands > Hornby' 'Characters & Brands > LeapFrog'
#  'Games > Dominoes & Tile Games'
#  'Sports Toys & Outdoor > Bikes, Trikes & Ride-ons > Push Power Ride-ons & Accessories > Push Power Ride-ons'
#  'Games > Mystery Games'
#  'Cooking & Dining > Kitchen Tools & Gadgets > Barware > Straws'
#  'Games > DVD Games' 'Games > Trivia & Quiz Games'
#  'Electronic Toys > Educational Computers & Accessories'
#  'Women > Tops & T-Shirts' 'Characters & Brands > Upstarts > Family Games'
#  'Dolls & Accessories > Fashion Dolls & Accessories > Fashion Dolls'
#  'Cooking & Dining > Kitchen Tools & Gadgets > Barware > Glass Markers & Charms'
#  "Arts & Crafts > Children's Craft Kits > Children's Knitting & Textile Design"
#  'Novelty Jewellery > Charms > Bead Charms'
#  'Games > Travel & Pocket Games' 'Games > Drinking Games']
# -----------------------------------
# Unique value of customers_who_bought_this_item_also_bought: ['http://www.amazon.co.uk/Hornby-R8150-Catalogue-2015/dp/B00S9SUUBE | http://www.amazon.co.uk/Hornby-Book-Model-Railways-Edition/dp/1844860957 | http://www.amazon.co.uk/Hornby-Book-Scenic-Railway-Modelling/dp/1844861120 | http://www.amazon.co.uk/Peco-60-Plans-Book/dp/B002QVL16I | http://www.amazon.co.uk/Hornby-Gloucester | http://www.amazon.co.uk/Airfix-5014429781902'
#  'http://www.amazon.co.uk/Christmas-Holiday-Express-Festive-Train-Set-Toy/dp/B009R8S8AA | http://www.amazon.co.uk/Goldlok-Holiday-Express-Operated-Multi-Colour/dp/B009R8PAO2 | http://www.amazon.co.uk/FunkyBuys%C2%AE-Christmas-SI-TY1017-Ornaments-Operated/dp/B01437QMHA | http://www.amazon.co.uk/Holiday-Express-Christmas-Ornament-Decoration | http://www.amazon.co.uk/Seasonal-Vision-Christmas-Tree-Train/dp/B0044ZC1W2 | http://www.amazon.co.uk/Coca-Cola-Santa-Express-Train-Set/dp/B004BYSNU0'
#  'http://www.amazon.co.uk/Classic-Train-Lights-Battery-Operated/dp/B0041L9OHE | http://www.amazon.co.uk/Train-With-Tracks-Battery-Operated-x/dp/B009P540O8 | http://www.amazon.co.uk/13-Piece-Train-Set-Ideal/dp/B0173N6E4W | http://www.amazon.co.uk/Train-Flash-Electric-Sound-Europe/dp/B008D7CEH4 | http://www.amazon.co.uk/Train-Ultimate-Sticker-Book-Stickers/dp/1405314516 | http://www.amazon.co.uk/Train-Stickers-Dover-Little-Activity/dp/0486403106'
#  ...
#  'http://www.amazon.co.uk/Batman-1966-Series-Action-Figures/dp/B00C16YYW6 | http://www.amazon.co.uk/Batman-1966-Series-Action-Figures/dp/B00C16YZ2U | http://www.amazon.co.uk/Batman-1966-Series-Action-Figures/dp/B00C16YWXC | http://www.amazon.co.uk/Batman-1966-Series-Action-Figures/dp/B00C16YYVC | http://www.amazon.co.uk/Penguin-Comics-Multiverse | http://www.amazon.co.uk/Batman-1966-Series-Action-Figures/dp/B00C16YZ4S'
#  'http://www.amazon.co.uk/Storm-Trooper-Costume-Childs-Outfit/dp/B00QKBG57K | http://www.amazon.co.uk/STAR-WARS-AWAKENS-Stormtrooper | http://www.amazon.co.uk/Star-Wars-Costume-Stormtrooper | http://www.amazon.co.uk/Rubies-Costume-Star-Wars-Stormtrooper | http://www.amazon.co.uk/STAR-WARS-Stormtrooper | http://www.amazon.co.uk/Deluxe-Stormtrooper'
#  'http://www.amazon.co.uk/Bandai-Star-Wars-Fighter-Model/dp/B00RYSAWVS | http://www.amazon.co.uk/Bandai-Star-Wars-Starfighter | http://www.amazon.co.uk/Star-Wars-48-Snow-Speeder/dp/B00U7A8MT4 | http://www.amazon.co.uk/Bandai-Advanced-Starfighter | http://www.amazon.co.uk/Star-Wars-fighter-resistance | http://www.amazon.co.uk/Millennium']
# -----------------------------------
# Unique value of description: ['Product Description Hornby 2014 Catalogue Box Contains 1 x one catalogue'
#  'Size Name:Large FunkyBuys® Large Christmas Holiday Express Festive Train Set (SI-TY1017) Toy Light / Sounds / Battery Operated & Smoke'
#  'BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT ENGINE SOUND BOXED KIDS BATTERY Railway Train Set with Light Sound, Big Size Curved Track Free Wheeling Action Working Headlight Sound Horn The Track Can Also Be Assembled In More Layouts Length Of Track 104 cm WIDTH OF THE TRACK 68 CM Finely Detailed Realistic Toy Train REQUIRES 2 AA BATTERIES (NOT INCLUDED)'
#  ... 'DC 66 Batman Classic TV Series 6 Inch Riddler Action Figure'
#  '*Includes 1x Badge with holder and chain *High quality metal construction *Ball clasp necklace *Removable from holster, features heavy duty pin design *Brand new'
#  'Designed by Ed BenesIt\'s here - the third series based on the popular DC Comics series, JUSTICE LEAGUE OF AMERICA, written by New York Times best-selling author Brad Meltzer and illustrated by Ed Benes! Green Lantern, Wonder Woman, The Flash and Geo-Force are the latest JLA heroes to be made into action figures!- Green Lantern - 6.75" HEach figure features multiple points of articulation and a base. 4-color blister card packaging.']
# -----------------------------------
# Unique value of product_information: ['Technical Details Item Weight640 g Product Dimensions29.6 x 20.8 x 1 cm Manufacturer recommended age:6 years and up Item model numberR8148 Main Language(s)English manual, English Number of Game Players1 Number of Puzzle Pieces1 Assembly RequiredNo Scale1:72 Engine Typeelectric Track Width/GaugeHO Batteries Required?No Batteries Included?No Material Type(s)Paper Material Care InstructionsNo Remote Control Included?No Radio Control Suitabilityindoor Colorwhite \xa0\xa0 Additional Information ASINB00HJ208KO Best Sellers Rank 52,854 in Toys & Games (See top 100) #69 in\xa0Toys & Games > Model Trains & Railway Sets > Rail Vehicles > Trains Shipping Weight640 g Delivery Destinations:Visit the Delivery Destinations Help page to see where this item can be delivered. Date First Available24 Dec. 2013 \xa0\xa0 Feedback \xa0Would you like to update product info or give feedback on images?'
#  'Technical Details Manufacturer recommended age:3 years and up Item model numberSI-TY1017-B \xa0\xa0 Additional Information ASINB01434AIRS Best Sellers Rank 169,625 in Toys & Games (See top 100) #261 in\xa0Toys & Games > Model Trains & Railway Sets > Rail Vehicles > Trains Delivery Destinations:Visit the Delivery Destinations Help page to see where this item can be delivered. Date First Available18 Aug. 2015 \xa0\xa0'
#  'Technical Details Manufacturer recommended age:3 years and up \xa0\xa0 Additional Information ASINB00E5MNXJ4 Best Sellers Rank 54,147 in Toys & Games (See top 100) #72 in\xa0Toys & Games > Model Trains & Railway Sets > Rail Vehicles > Trains Delivery Destinations:Visit the Delivery Destinations Help page to see where this item can be delivered. Date First Available25 July 2013 \xa0\xa0 Feedback \xa0Would you like to update product info or give feedback on images?'
#  ...
#  'Technical Details Item Weight159 g Product Dimensions7.6 x 7.6 x 2.5 cm Manufacturer recommended age:14 years and up Manufacturer reference4868 \xa0\xa0 Additional Information ASINB00K0M35B4 Best Sellers Rank 496,947 in Toys & Games (See top 100) Shipping Weight159 g Delivery Destinations:Visit the Delivery Destinations Help page to see where this item can be delivered. Date First Available29 April 2014 \xa0\xa0 Feedback \xa0Would you like to update product info or give feedback on images?'
#  'Technical Details Item Weight181 g Product Dimensions21.6 x 15.2 x 34.3 cm Manufacturer recommended age:14 years and up Item model numberJUN080337 \xa0\xa0 Additional Information ASINB001AZV832 Best Sellers Rank 1,304,952 in Toys & Games (See top 100) #136340 in\xa0Toys & Games > Figures & Playsets Shipping Weight181 g Delivery Destinations:Visit the Delivery Destinations Help page to see where this item can be delivered. Date First Available1 Oct. 2013 \xa0\xa0 Feedback \xa0Would you like to update product info or give feedback on images?'
#  'Technical Details Item Weight299 g Product Dimensions30 x 19 x 7 cm Manufacturer reference160209 Assembly RequiredNo Batteries Required?No Batteries Included?No \xa0\xa0 Additional Information ASINB00WW4FDBI Best Sellers Rank 21,788 in Toys & Games (See top 100) Shipping Weight299 g Delivery Destinations:Visit the Delivery Destinations Help page to see where this item can be delivered. Date First Available27 July 2015 \xa0\xa0 Feedback \xa0Would you like to update product info or give feedback on images?']
# -----------------------------------
# Unique value of product_description: ['Product Description Hornby 2014 Catalogue Box Contains 1 x one catalogue'
#  'Size Name:Large FunkyBuys® Large Christmas Holiday Express Festive Train Set (SI-TY1017) Toy Light / Sounds / Battery Operated & Smoke'
#  'BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT ENGINE SOUND BOXED KIDS BATTERY Railway Train Set with Light Sound, Big Size Curved Track Free Wheeling Action Working Headlight Sound Horn The Track Can Also Be Assembled In More Layouts Length Of Track 104 cm WIDTH OF THE TRACK 68 CM Finely Detailed Realistic Toy Train REQUIRES 2 AA BATTERIES (NOT INCLUDED)'
#  ... 'DC 66 Batman Classic TV Series 6 Inch Riddler Action Figure'
#  '*Includes 1x Badge with holder and chain *High quality metal construction *Ball clasp necklace *Removable from holster, features heavy duty pin design *Brand new'
#  'Designed by Ed BenesIt\'s here - the third series based on the popular DC Comics series, JUSTICE LEAGUE OF AMERICA, written by New York Times best-selling author Brad Meltzer and illustrated by Ed Benes! Green Lantern, Wonder Woman, The Flash and Geo-Force are the latest JLA heroes to be made into action figures!- Green Lantern - 6.75" HEach figure features multiple points of articulation and a base. 4-color blister card packaging.']
# -----------------------------------
# Unique value of items_customers_buy_after_viewing_this_item: ['http://www.amazon.co.uk/Hornby-R8150-Catalogue-2015/dp/B00S9SUUBE | http://www.amazon.co.uk/Hornby-Book-Model-Railways-Edition/dp/1844860957 | http://www.amazon.co.uk/Peco-60-Plans-Book/dp/B002QVL16I | http://www.amazon.co.uk/Newcomers-Guide-Model-Railways-Step/dp/1857943295'
#  'http://www.amazon.co.uk/Christmas-Holiday-Express-Festive-Train-Set-Toy/dp/B009R8S8AA | http://www.amazon.co.uk/Goldlok-Holiday-Express-Operated-Multi-Colour/dp/B009R8PAO2 | http://www.amazon.co.uk/FunkyBuys%C2%AE-Christmas-SI-TY1017-Ornaments-Operated/dp/B01437QMHA | http://www.amazon.co.uk/Holiday-Express-Christmas-Ornament-Decoration'
#  'http://www.amazon.co.uk/Train-With-Tracks-Battery-Operated-x/dp/B009P540O8 | http://www.amazon.co.uk/Classic-Train-Lights-Battery-Operated/dp/B0041L9OHE | http://www.amazon.co.uk/Train-Flash-Electric-Sound-Europe/dp/B008D7CEH4 | http://www.amazon.co.uk/13-Piece-Train-Set-Ideal/dp/B0173N6E4W'
#  ...
#  'http://www.amazon.co.uk/Playskool-Heroes-Super-Adventures | http://www.amazon.co.uk/Playskool-Heroes-Marvel-Spider-Man-Adventures | http://www.amazon.co.uk/Playskool-Marvel-Adventures | http://www.amazon.co.uk/Marvel-A5665-Spiderman-Strike-Tank/dp/B00HAFN5IC'
#  'http://www.amazon.co.uk/Storm-Trooper-Costume-Childs-Outfit/dp/B00QKBG57K | http://www.amazon.co.uk/Star-Wars-Trooper-Costume-Medium/dp/B000FDSKZ4 | http://www.amazon.co.uk/Clone-Trooper-Captain-Wars%C2%99-costume/dp/B0026OL3XG | http://www.amazon.co.uk/Star-Wars-Electronic'
#  'http://www.amazon.co.uk/Olde-Scotland-Yard-Ltd-Lawkeeper/dp/B00K5D2RM6']
# -----------------------------------
# Unique value of customer_questions_and_answers: ['Does this catalogue detail all the previous Hornby products please? // HiThe 2014 catalogue does indeed detail previous models but also includes new releases for 2014.You would be advised to purchase models as you need them to avoid them being discontinued in subsequent years…\n    \n      see more\n    \n  \n  \n    HiThe 2014 catalogue does indeed detail previous models but also includes new releases for 2014.You would be advised to purchase models as you need them to avoid them being discontinued in subsequent yearsHope this helps\n    \n      see less'
#  'can you turn off sounds // hi no you cant turn sound off'
#  "What is the gauge of the track // Hi Paul.Truthfully, I'm not sure. But it's very much alike to a 00 gauge. But this train set isn't an add-on for an electric train set nor has nothing to do with one.I bought this for my 4 year old nephew as he adores trains but is far too young for an electric set. He was VERY happy with this though! | what is the layout of the tracks? // Its an oval shape layout"
#  nan
#  "is it possible to replace thr grain of wheat lamps with leds // Hi Pete. No it's not possible the main pole is to thin to take readily available LEDs wiring. I was hoping to do this myself but it would mean rewireing the LEDs with thin enough wire that I have not managed to track down yet. I will be trying by using the existing wire. Tricky job cutting the tops off the lantern and …\n    \n      see more\n    \n  \n  \n    Hi Pete. No it's not possible the main pole is to thin to take readily available LEDs wiring. I was hoping to do this myself but it would mean rewireing the LEDs with thin enough wire that I have not managed to track down yet. I will be trying by using the existing wire. Tricky job cutting the tops off the lantern and hoping I can pull enough wire through to solder the led back on. That I will be trying in the next few months. Hope I may have been some help, good luck. Derryck\n    \n      see less"
#  "Can this train go backwards as well as forward? // Yes.  Variable speed in both directions. | Is this train set OO Gauge. // Yes it is. | can it sit directly on carpet or will i need a board to put it on ? // The train set can be run on carpet, although a board is more beneficial. | Hi does this play Christmas sound effects thanks // Hi no sound effects. | is the carriages and engine hard plastic? // Yes, they are. It is a lovely piece, kids loved it, the grown ups even more! | How long is the track? // It's about 4 feet long each side, Then there's the 2 bends one each end. | How long is the Santa express train and its carriages in total from engine to end of last carriage?  Thanks // 12 inches long."
#  'The description is incorrect.  the hornby site provides the following; contents: gwr ‘ketley hall’, hall class 4-6-0 locomotive, correct? // Another Seller has entered the wrong description, you are right - it is the Ketley Hall locomotive.'
#  "I'm guessing this is the railroad version, as the detail is very poor. Please advise. // This model is in the Hotnby Railways range rather than the RailRoad range however only just, the detail is decent for the price including the sound decoder and speaker yet could be better."
#  'In the uk isthere extra import duty or tax to pay ? // Dear friends.Thank you for your question.Price in the sale screen in the Amazon, because they are displayed in including the value-added tax (VAT) price, should never tax is applied by another in this price.…\n    \n      see more\n    \n  \n  \n    Dear friends.Thank you for your question.Price in the sale screen in the Amazon, because they are displayed in including the value-added tax (VAT) price, should never tax is applied by another in this price.We only examined still some.So may not be accurate, I will leave to check a little more detail.Take some time now.Best regards.\n    \n      see less'
#  "Can the train set lie on carpet? // Unlikely | If one migrates to DCC later, do you have to run this on separate track, or will it run on the track however not be controllable? // Don't know Dave. I'm just a 63 year old leaner. I've always wanted a. Train set I'm into G gauge at the momentAlso 00 gauge and N gauge.  Sorry. Steve"
#  'is this a model tram or is it a moving model with track? // It is a model which runs on N Gauge track.'
#  'what is the difference between this model and the Green model for 14 plus age group // Hi,  Apart from some minor detailing I believe their is very little difference.                             Regards John,, Shop Amazon Ltd'
#  'The 2 wires are black and a bare silver wire. do I assume the bare wire is red a red connection and the black for neutral. Is 6V per lamp or for the 20. // The type of bulb used is called a fillament therefore there is no positive or negative it does not matter which wore you use to connect with the supply.  Each lamp post is rated at maximum 6V but due to the heat from the bulb only light the lamp post for 30minutes at a time beacuse the plactic may melt.  However I have…\n    \n      see more\n    \n  \n  \n    The type of bulb used is called a fillament therefore there is no positive or negative it does not matter which wore you use to connect with the supply.  Each lamp post is rated at maximum 6V but due to the heat from the bulb only light the lamp post for 30minutes at a time beacuse the plactic may melt.  However I have found by connecting 3 lamp posts in series then use 12V the effect is good and they can be run for a longer period.  Hope this helps you\n    \n      see less'
#  'Are these talking ones exactly the same size as the others? Very difficult to tell // Yes, all exactly same scale.'
#  "I have two boys and can imagine them fighting over this, can a second locomotive be added easily? // Yes, in fact I have a second set unused I am selling still in box for £85, there would no arguments then!, Mel @mel22@fsmail.net if interested. | Is this set from the Railroad range? // Sorry I don't know, it was bought for my grandson. The only thing I can tell you is that it is compatible with 00 guage. | How much track comes in the box?  Is there enough for a continual loop/oval?  My 4 YO  grandson is train crazy and was thinking of getting it for him // Hi. Yes there is enough for a continual loop. You can also buy extra track should you want to make the loop bigger. | Is it three rail // No, it is oo two rail non digital. | Is this set DCC ready? // Hi yes it is, printed as such on the side of the box | is this a nickel silver track? // Yes"
#  'please can you tell me if this train work on Hornby anologe track // Yes'
#  'is it DCC // It is not DCC i.e. it does not have a 6 pin DCC socket so a wired DCC decoder will need to be fitted.  http://sumidacrossing.org/Collection/ This link provides information on many JR locos'
#  'what size are the figures please ? // Hi, they are about 8" inches perhaps more. My son loves them.'
#  'Does he says actual phrases or is only the breathing sounds? // Says "The force is strong with this one!", "I find your lack of faith disturbing!" and "I am your father" as far as I can recall... plus the breathing sound'
#  'Which colour do you get?  I want both (two kids, not for me!) but I\'d like one of each colour! // Please contact Amazon once you have placed your order. They will be able to send you 1 of each rabbit. | Does anyone know if this toy bunny fits in the toy rabbit hutch ("frequently bought together")? // It will fit through the door but not into the hutch'
#  'post to greece // Hi, Yes we can still post to Greece in time for Christmas, you must order and pay for the item as soon as you can Monday the 9th December is the last posting day.Kind RegardsRobin…\n    \n      see more\n    \n  \n  \n    Hi, Yes we can still post to Greece in time for Christmas, you must order and pay for the item as soon as you can Monday the 9th December is the last posting day.Kind RegardsRobinDobege\n    \n      see less'
#  'Re: "Light-gauge metal frame for posing" - to what extent are these "poseable"? Also, any risk of damage if over bent? // The one I got was very sturdy however I don\'t think there is much room for posing to be honest, my pug loved it and tore it to bits but they are tough unless like me you give it to a dog \uf436 | Is this dog washing washable? // Not sure as it is a Christmas gift ..'
#  'Are the dimensions taken from the tip of the trunk to the end of the tail? or is it the length of the body that is 77cm in length? // the animal measures about a metre from the middle of the trunk (this is the farthest part as the trunk curls up and in a bit)  to its rear and the tail hangs down  - if you pulled the tail out and measured to the end it would be around 110/120 in total  - the animal is quite squishy so precise measuremnts are difficult…\n    \n      see more\n    \n  \n  \n    the animal measures about a metre from the middle of the trunk (this is the farthest part as the trunk curls up and in a bit)  to its rear and the tail hangs down  - if you pulled the tail out and measured to the end it would be around 110/120 in total  - the animal is quite squishy so precise measuremnts are difficult - hope this helps  - its a nice quality item\n    \n      see less'
#  "Is Elmar jointed? // Yes he is fully jointed on head,arms and legs. | Does it growl // NO - unless you are a ventriloquist | Hi What are the sizes of this bear? Thanks // The bear I got is 40cm from Head to heel standing up. its waist size is 38cm I know because I made a jumper for it, I know mad. It is a lovely quality bear the children love it. It looks like the Teddington Bear from Show Show cbees tv show that's why I bought it | how are these so cheap compared with other steiff bear sites? // Not sure but I do know that they are the real thing and customers seem to matter most with this company | Did this bear come in a steiff box? // No it didn't"
#  "Hi there,  what is the name on the collar of this dog? // Hi, The name is 'Buttons'. He is very sweet :)"
#  "is it suitable for a 9 month baby // Yes I think it's ok"
#  'Does the item come boxed and with an official certificate? // Yes in a box and certificate'
#  'Hi just a query about the Super Boggle, is that a picture of the actual box it looks immaculate if it is as i want to give as present // I am not selling this, but when I ordered a used version of Boggle for a gift, the box was in very good condition with just a dent in one corner.'
#  'Is the postage multiplied by number of sets ordered? // No. There is a base charge and then a charge for the weight. | If I buy 2 packs is there any chance you can guarantee me 5 dice each of 6 different colours? // If you put a note against the order then we will do our best to meet your request, if this is not possible we will get back to you before shipping.Gary'
#  'whats the size of the snakes and ladder mat ? // Its around 28inchs wide and long. Its a decent size and decent plastic. Its not too flimsy'
#  'how big are these? // Approximately 5cm cubed'
#  'Is this a travel game? Small enough to put in a suitcase // Yes the box is not to big about size of a tissue box, could also be stored out of box in it own bag that comes with it.  Hope this helps'
#  "My 98 year old mother can't see very well but would love a word game likes this. How big are the dice? // The dice are a white 15mm cube, with different coloured letters on the faces. My mother aged 94 would have difficulty handling them. But they are fun to play with."
#  'I have broken crosswords timer. How long is it? // I have no idea but will run mine and time it and let you know'
#  "What's the best number of people for this game? // At least 2. No More than 4."
#  'how many dice in a pack? // The bag contains 100 7mm dice'
#  'Are the faces indented into the dice or just printed on top? // Hello,all of our dice are engraved and then painted.Q-workshop'
#  "How many cubes do U get? // Bought them for my niece - think there's 9 in a pack - excellent learning tool | how many cubes do u get // The pack I bought contains 9 story cubes. There is a picture on each face of each cube. Pamela"
#  'What size are the cards? Are they laminated? // 8 inches by 4 inches approx. no, far from being laminated, they were paper thin. You would need a board under them to use. And, the box for each beetle was far too small. Youngsters could not possibly draw within the space provided. I was extremely disappointed and threw them in the bin!'
#  'Are all the dice white or mixed as shown in the picture // mixed'
#  "Does it come with a big enough tray to play in? // The box is the tray. It's big enough to play with. | is it like kinetic sand // Yes I think it is.  Have never owned Kinetic sand but this is brilliant - cross between sand and play dough - so perfect - never dries out, can't be trodden into carpets and my four year old LOVES it"
#  'Hi, Please can you confirm whether this includes a tray for the sand? The description says it does but it isnt shown on the picture. Thank you // Yes, this comes with a tray that can be used to store the Play Sand. | Is this regular sand or the kinetic sand stuff that never dries out and flows? // This is definitely not normal sand. It is the magic type of sand that never dries out and flows!'
#  "Would this be ok for a 2 year old? // HalloI think no because this is only  4-10 years. The parts are too small Regression…\n    \n      see more\n    \n  \n  \n    HalloI think no because this is only  4-10 years. The parts are too small RegressionT.Bias\n    \n      see less | Can you re use it year after year? // You could if you were REALLY careful when opening each of the doors.  You would also need to make sure none of the items when missing before re packing ready for next year.  Realistically they are a single year use. Ours stay in the Christmas decoration box and get set up by the smalls each year and still very much enjoyed. | I can see the set only contains the four figures plus accessories, does in include the reindeer and sleigh? Thank you // Yes it does | Does anyone know what's the meaning of style A? // Hello Carey, no meaning, there is not differents styles, it must be a description generic or that came from other product. Best regards from Playmyplanet | What age is this product suitable for? // My daughter was 14 when she asked for this and she loved it | what size is the display // 46x24cm"
#  "Is this in english as I noticed on the box it is not written in english // I bought this last Christmas and my box was in English.  From what I remember, it shouldn't be a problem as the advent box numbers will be the same and I can't remember any instructions that were written, I think it was just pictures.  I've just bought two different ones for this year as our grandchildren loved them an…\n    \n      see more\n    \n  \n  \n    I bought this last Christmas and my box was in English.  From what I remember, it shouldn't be a problem as the advent box numbers will be the same and I can't remember any instructions that were written, I think it was just pictures.  I've just bought two different ones for this year as our grandchildren loved them and I think one of my choices is foreign.\n    \n      see less"
#  'Is the sand wet or dry? // Damp rather than wet'
#  'How many bags do you get for this? // One'
#  'can you confirm that i will receive the calendar in the picture (2013) edition? // This is the one I received but I did get mine quite a while ago lol'
#  "I have seen a few videos online reviews etc... i would like to know how easy it is to Free-style model this? (like upright towers etc) // Although the sand is easily moulded.. it is very soft and doesn't hold its shape for very long. | Hi.. Is this the same stuff as kinetic sand?  Thanks :) // Yes it is | Can this be used in a sandpit? // I think this is meant to be used indoors only, useful on bad weather days for play.We use plastic sheet to prevent mess,but sand easily removed from carpet with vacuum cleaner. | Does the product come in a tub or a plastic bag? Just want to know if I need to buy any extras. // Its in a bag, I store it perfectly well in an ice-cream tub."
#  "what is the dimension of those small boxes？ // The drawers are 4.5 x 4.5 x 5.5 cm's.Colin - Bort Shopping. We're currently running a 3 for 2 offer on these Advent Gift Boxes here on Amazon."
#  "what other figures can I buy to go with this set? // You could buy clone troopers, chewbacca, any jedi's, really anything you would like. Many thanks shawn | do this this come in the original box in separate packs? // If I understand the question correctly, there were two bags inside the box, one containing the very small pieces."
#  "is this the 2014 version? // No I believe it is last years | I'm buying this as a keep sake, it doesn't show the box, I assume it comes all boxed up?  That might be a silly question. // Yes it's a boxed play-scene"
#  'Can you mix it with other motion sand makes // I have never tried to be honest.'
#  'How big is the box that is used as the playscene? Is there enough sand to fill it or should I buy extra? // You can buy more, it is not too much'
#  "How much do you get? does anyone know in grams/volume? Thanks :-) // It's not a lot really. A large cupful. Sorry don't have the box so can't say exactly. But honestly it's worth it :)"
#  "does this have little chocolates behind each door? // Hi Rachel, no this isn't a chocolate advent, sorry.  Squashed Tomato Ltd"
#  "Is there a box with the sand? // No. Just a tub and some extras. | What is suitable for a 7 yrs // I bought for my 2 year old, I would say if they are particularly into crafty stuff then a 7 yr would enjoy it. Much more 'interesting' than play dough."
#  "Is this wall mountable? // It does not have any fixings to attach to a wall, but it would be easy to attach a picture hook fixing yourself I would think. | Please can you tell me how the holiday poem goes? // Each evening when goodnights are said,Take off one link and hop into bed.When only the star is left to shine,…\n    \n      see more\n    \n  \n  \n    Each evening when goodnights are said,Take off one link and hop into bed.When only the star is left to shine,Then you will know it's Christmastime!\n    \n      see less"
#  'What type of pictures are behind the doors? // They are varied and pretty'
#  "does it have a lid? If not how do you store the sand? // It comes in a pretty sturdy cardboard box with lid, as pictured. My little boy uses the box as a tray while he's playing with the sand too which keeps it contained in one place nicely! Then I put the sand back in the press and seal bag that it came in, in the box, and then keep it all in the together in the box. | Can i have the dimensions of the box please? // 29cm×26cm×5.5cm"
#  'Is it 12 days or 24? // 24'
#  "Could you please tell me the dimensions of the tray - height, width and length preferably in cms ? // Sorry can't help it was for my granddaughter for Christmas last year | How do you store the sand? does it come with a box to store it in? // There comes a plate in it, there you can store it. You don't need a box, because it won't dry out. | is this safe with a dog in the house // If you don't let your dog eat it then yes, its safe."
#  'How much sand is needed to fill up a 700ml bottle? // It would take two of the colours to fill up a 700ml bottle ( so you would have 6 colours left)'
#  "how big are the figurines? eg. what size is the smallest part? // Hi....can't remember which was smallest.  Rabbit etc I think. Bought for my grandson who was 2 then. He loved opening it & setting things in a scene x | What is the age recommendation on this toy?  My son is 22 months, the writing states that it's suitable for toddlers but the pieces look small on pic // It is part of the 123 range suitable from one and up | Is this suitable for a 4 year old? // This product is more aimed at 18months-3 year old. There are other Playmobil advents available for ages 4+. | I know my animals, but what is a Fuchs? // It's a fox in German"
#  'roughly does anyone know how many small plastic bottles this sand would fill? // It was a long time ago we had our sand...but I do remember there was a lot of sand left over!!! We filled at least 8 bottles  with over half left. Still using it now....'
# ...
#  "can you tell me what size this is please ????? // no - its packed away. sorry.  I'm sure if you google it you will find the info - best of luck!"
#  'What are the beads made of, are they wood or plastic? // The beads are all plastic.'
#  'Do you know what these are made from (acrylic or plastic)? // Does not say on the package.  They are nice to handle, fairly heavy for their size and and do not roll a lot.  I got them to play vocabulary games with international business students - like the story cubes for children.  They work well, you can use words or pictures.  Can be written on with washable felt tip (water ge…\n    \n      see more\n    \n  \n  \n    Does not say on the package.  They are nice to handle, fairly heavy for their size and and do not roll a lot.  I got them to play vocabulary games with international business students - like the story cubes for children.  They work well, you can use words or pictures.  Can be written on with washable felt tip (water gets it off) or permanent marker (label remover gets it off). [board markers are useless]  Does the supplier know the material?\n    \n      see less'
#  "How do I send you a message to request specific colours of dice? // make your order. go into your orders, select the one you just made, then select 'contact seller' - we can provide red, blue, green, yellow, purple, orange, black or white. Legendgames. | Can I choose the colors? I would like 2 oranges, 2 greens and one random // As long as we have the colours in stock (which we currently do) that shouldn't be a problem. Add a message to your order.Gary | Can I have combined postage if i want to buy 2 items? // Just buy the 10 pack instead of two 5 packs. | Are these the same dice as sold in single sets? e.g. 'Poly Dice Set, Purple, 7 Polyhedron Dice....' Thanks. // Yes.  They are in different bags."
#  'What would the ostage be if I bought 5 // If all placed on one order the delivery cost would be £3.99Kind RegardsWitzigs Games'
#  'How big are the die? // They are normal game playing ones. About 1.5cm'
#  'i want to know if is wooden? // No it is plastic both the rummy pieces and tile holders too.'
#  'What region is the DVD specific to? // Region 2 Europe'
#  'Is this dvd all regions? does it play on european dvd players (rc2)? // Yes it does.'
#  'Does the name "Goliath" refer only to the maker, or does it also signify a larger than normal version of the game? Poor sight needs the latter. // It  refers to the maker. The game is a deluxe and not a travel one. I made that mistake and bought a cheaper version which turned out to be a travel one. Very small. It is wise to pay that bit extra to get a large one. Good game.'
#  'do the stones have a reasonable weight // They are plastic so they are quite light. | Are there any bowls or containers to hold the stones? // I bought as a present last Christmas but as I recall no, you need to find your own bowls. | Does this set include the rules/instructions, how to play? // It does but only a very basic explanation. I also bought the book "Go for beginners" by Kaoru Iwamoto and that explains the rules in more depth, as well as some excellent advice for people learning the game.'
#  "can you mix the races up so that you can play the game more than once with different winners // Hi Alison, there are 30 different races (which although we haven't yet played this) appears to take 20 minutes each so you have some 10 hrs of entertainment.I hope this helps | Does the commentary name the dogs or can you sell ownership of the dogs and allow owners to name them in order to raise more money for charity? // We auction the dogs of by making our own programes for the race card."
#  "Can I buy an up to date set of cards and DVD for the fifa scene it game // Hi Nina, I'm not aware of any current add ons for cards and dvds. I will see if can locate some for you and get back to you asap with a result. Regards, Tim. Finleys"
#  'Are the rows cut at an angle,so that the tiles lean away from you?  What is the width of the cut row - are they suitable for 8mm thick tiles? // The dominoes lean away from you. They would take 8mm tiles. They are ideal for elderly or infirm players where their hands may not cope.'
#  "Is this a word or a number game?  The picture shows number tiles and not letter tiles. // It's a number game."
#  'what is the measurement of the dominoes // 9cmx4.5cm'
#  'what size are the dominoes? // The dominos are 5cm by 2cm by 0.5cm. Hope that helps.'
#  "How many dominoes are in the box? // Sorry gave it as a present so can't count them."
#  'Does it come with the 2015 convention sticker? Your previous answer says yes but description says no // Mine came with the sticker | does it come with the summer convention sticker // yes, it does'
#  'does it come with the exclusive sticker // The Geek inc one comes with an underground toys exclusive sticker'
#  "Is this metal // Yes it is | Is this metal? // Yes and it's got a good weight to it | Can you separate the batarang from the actual display? // Yes you can."]
# -----------------------------------
# Unique value of customer_reviews: ["Worth Buying For The Pictures Alone (As Ever) // 4.0 // 6 April 2014 // By\n    \n    Copnovelist\n  \n on 6 April 2014 // Part of the magic for me growing up as a boy was to buy (or be given) the new Hornby catalogue every year, even if it included 90% of the same products as the previous year.  I've still got my old ones dating back to the 70s and 80s somewhere.  These days the catalogue is especially informative in that it tells you the vintage of the rolling stock which is useful if you are dedicating your railway to one particular era and train company. | Amazing detail fabulous photography. // 5.0 // 11 April 2015 // By\n    \n    richard\n  \n on 11 April 2015 // Amazing detail, every credit to the photographer in this book, a worthy reference manual, as well as a sales brochure. even if you only have a passing interest in the hobby you will be transported to another time when we were all younger and in awe of the big trains. | 'Great Purchase' // 5.0 // 23 April 2014 // By\n    \n    Pinkhandbag\n  \n on 23 April 2014 // This was purchased on behalf of my Dad. He is always asking me to look up 00 gauge engines online, so this has been a good buy as he can look at it anytime. Would definitely buy the next one 2015!It arrived quickly and in perfect condition :-) | Great Catalogue // 5.0 // 11 Jun. 2014 // By\n    \n    Gary John Mapson\n  \n on 11 Jun. 2014 // Everything I really needed to see what was on offer from Hornby in the way of trains.  Would not have minded it included an RRP as well though | I collect them all as the glossy pictures are great and it is nice that you can still get ... // 5.0 // 7 Dec. 2014 // By\n    \n    David Baker\n  \n on 7 Dec. 2014 // I collect them all as the glossy pictures are great and it is nice that you can still get catalogs to collect. | Great catalogue // 5.0 // 20 Mar. 2015 // By\n    \n    John A. Day\n  \n on 20 Mar. 2015 // What a great book.  Extremely useful insight to all future christmas presents. | Useful // 5.0 // 7 Oct. 2014 // By\n    \n    T. Davies\n  \n on 7 Oct. 2014 // Useful info for someonelike me starting back into the hobby after many years | hornbys latest catalogue. // 5.0 // 1 Dec. 2014 // By\n    \n    John Butlin\n  \n on 1 Dec. 2014 // A well produced very good quality catalogue.Super quality pictures."
#  'Four Stars // 4.0 // 18 Dec. 2015 // By\n    \n    kenneth bell\n  \n on 18 Dec. 2015 // Very happy with the communication with funkybuys | Five Stars // 5.0 // 14 Jan. 2016 // By\n    \n    moosixty\n  \n on 14 Jan. 2016 // Great buy.'
#  "**Highly Recommended!** // 5.0 // 26 May 2015 // By\n    \n    Simon.B :-)\n  \n on 26 May 2015 // Simple & GREAT FUN for 5+My nephews face was amazing when he opened this for his birthday!! His mouth dropped open with surprise! (no joke, it literally did!)It's very easy to connect the plastic track/assemble, it takes 2 mins. It's very easy to connect the trains together and apply to track.All you need is two AA batteries and time to watch your child enjoy themselves!We even added homemade tunnels to this to make it more fun, we simply cut holes in cardboard boxes to put around certain parts of the track!This is brilliant for very young kids if they're very interested in trains. This gets them started in the hobby and doesn't cost much at all! | Excellent product // 5.0 // 29 Jun. 2014 // By\n    \n    Trevor\n  \n on 29 Jun. 2014 // Excellent product everybody should have one or to of product  excellent  100 percent ok speedy delivery excellent i give it five stars CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT ENGINE BOXED BOYS KIDS BATTERYdouble aa battery goes in top of engine | Review book finding love again // 5.0 // 20 Aug. 2015 // By\n    \n    Janet\n  \n on 20 Aug. 2015 // I was extremely pleased with the train set really good value for money. | I would not recommend this item // 1.0 // 11 Dec. 2015 // By\n    \n    ann milburn\n  \n on 11 Dec. 2015 // i found this item, not suitable for young children,  very difficult to keep the carriages together and the whole thing kept coming off the track.All very thin plastic. I would not recommend this item. | ... for my young nephew for Christmas I was very disappointed but as it was only £7 it was not ... // 1.0 // 11 Jan. 2016 // By\n    \n    T. F. Snowdon\n  \n on 11 Jan. 2016 // The Train did not work  and as it was a present for my young nephew for Christmas I was very disappointed but as it was only £7 it was not worth the fuss of ordering another | Better than expected // 4.0 // 22 Dec. 2015 // By\n    \n    Kindle Customer\n  \n on 22 Dec. 2015 // Better than expected. It has a proper oval of track rather than just a circle. My 2 year old grandsn loves it although he finds it difficult to put on the track. | Brilliant little train // 5.0 // 28 Dec. 2015 // By\n    \n    LorsF\n  \n on 28 Dec. 2015 // Brilliant little train.  Bought for my son who was looking for a train that looks like the polar express - he was not disappointed.  Great value. | ok train , but carriages kept coming off track // 3.0 // 16 Dec. 2015 // By\n    \n    mrs nice\n  \n on 16 Dec. 2015 // train carriages kept falling track  of and the connectors not good. better on the floor"
#  ...
#  'Five Stars // 5.0 // 18 Dec. 2015 // By\n    \n    Amazon Customer\n  \n on 18 Dec. 2015 // arrived in excellent condition'
#  'The best sculpt in a while // 5.0 // 13 May 2010 // By\n    \n    Sodam Yat\n  \n on 13 May 2010 // Okay, Hal Jordan figures come and go. There is a new one just around the corner as I type; Hal is being reworked for the Blackest Night series of action figures. However, the thing is, unlike the majority of the figures on that ground breaking series, Hal sucks.I took one look and decided I wouldn\'t be pre-ordering it. He looks awful. His neck looks broken, his musculature is so ripped as to be almost jagged, points of articulation at the biceps and wrists make him look mechanical... I digress. Clearly DC Direct\'s exhaustive re-sculpt / re-paint binge on the various corps iterations of Hal that were sold at the 2009 Comic Con have left them little recourse but to go for a different look. It sucks.This is the superior figure. I ordered it based on the image, and I can happily say it doesn\'t do "Justice" to the actual product. This is a determined looking Hal Jordan, embodying Willpower with his steely glare and clenched fist. The paint job is nice, and the points of articulation are not too intrusive. The only points where they are blatant is a slight cuff/socket effect at the shoulders, but overall not too bad at all.He comes with the ubiquitous lantern, and a Justice League of America base on which to mount him, which works well. Kind of wish it was just the Green Lantern insignia, but never mind.'
#  'Gold leader // 5.0 // 31 Aug. 2015 // By\n    \n    graham mccoid\n  \n on 31 Aug. 2015 // 1st class kit top marks to bandai if your not very good at painting you dont need to its a snap fix kit but dont let that put you off keep them coming bandai | Fantastic kit! // 5.0 // 13 Oct. 2015 // By\n    \n    D A BROWN\n  \n on 13 Oct. 2015 // Fantastic kit, well fiddly and tiny parts, had to replace to broken bits of piping but that was my fault. Handy hint, don\'t fit the side pod engine on until you have placed all piping on the support wings, ignore what the planes say about this. For a kit only being 1:72 I was surprised by the size of the kit, with laser beams inserted its 30 cm long, Nice! You also get three pilot figures and two tiny (amazingly detailed) R2 units, which was nice. | NOT AS DESCRIBED // 2.0 // 5 Mar. 2016 // By\n    \n    bobby\n  \n on 5 Mar. 2016 // Ok so if you don\'t read these (like i didnt) then this wont help. Although it says "Assembly required: No" on the specifications this is actually a model kit with >100 tiny pieces. If thats your thing great but I was hoping it would be a more or less out the box thing. coming from Japan I cant return it as I must pay postage so its not worth it. maybe one day i\'ll get around to building it but probably not tbh. :/ ...  Y-Wings are cool so it still gets 2 stars... | Worth waiting for. // 3.0 // 13 Jan. 2016 // By\n    \n    souper\n  \n on 13 Jan. 2016 // I bought this model back in 15th December, had i known it was coming from Japan and that it would take so long i\'d have looked for it locally, needless too say i\'m mega-happy with it finally arriving last week and cannot wait until i get around to making it as i already have 3 others in the pipeline still to make. | Y-Wing Bandai - don\'t miss out // 5.0 // 21 Mar. 2016 // By\n    \n    Noswad\n  \n on 21 Mar. 2016 // This kit is awesome. Perfect for any who loves modelling and Star Wars. Bandai is definitely the best brand and beats all counterparts. The models once assembled are highly detailed and replicate the real thing down to a tee!! The Y-Wing in particular is a favourite. | A superb model which can be terribly fiddly and frustrating // 5.0 // 14 Mar. 2016 // By\n    \n    CB\n  \n on 14 Mar. 2016 // A superb model which can be terribly fiddly and frustrating. Keep with it and take your time and you will reap the rewards of a superb model. Probably the best in the series. Worth adding wear and tear and exhaust streaking for the finished look.']
# -----------------------------------
# Unique value of sellers: ['{"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", "Seller_price_1"=>"£3.42"}, {"Seller_name_2"=>"**stop-&-shop-uk**", "Seller_price_2"=>"£0.19"}, {"Seller_name_3"=>"World Wide Shopping Mall Ltd", "Seller_price_3"=>"£9.99"}, {"Seller_name_4"=>"MyHobbyStore Retail", "Seller_price_4"=>"£8.00"}, {"Seller_name_5"=>"francejouet", "Seller_price_5"=>"£37.62"}]}'
#  '{"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", "Seller_price_1"=>"£16.99"}}'
#  '{"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Seller_price_1"=>"£9.99"}, {"Seller_name_2"=>"DO NOT BUY - TESTING ACCOUNT", "Seller_price_2"=>"£29.90"}]}'
#  ...
#  '{"seller"=>[{"Seller_name_1"=>"Star Action Figures", "Seller_price_1"=>"£22.95"}, {"Seller_name_2"=>"Order66ToyStore", "Seller_price_2"=>"£19.99"}, {"Seller_name_3"=>"X-Comics GmbH", "Seller_price_3"=>"£21.28"}, {"Seller_name_4"=>"BALLABEG100", "Seller_price_4"=>"£25.00"}, {"Seller_name_5"=>"Japan-Select", "Seller_price_5"=>"£38.04"}]}'
#  '{"seller"=>[{"Seller_name_1"=>"YUK", "Seller_price_1"=>"£43.99"}, {"Seller_name_2"=>"DealsCentre", "Seller_price_2"=>"£116.50"}, {"Seller_name_3"=>"DALY store", "Seller_price_3"=>"£124.95"}]}'
#  '{"seller"=>[{"Seller_name_1"=>"Smaller World Future", "Seller_price_1"=>"£49.81"}, {"Seller_name_2"=>"Glendora Unique Store", "Seller_price_2"=>"£44.83"}, {"Seller_name_3"=>"M and N Media US", "Seller_price_3"=>"£32.19"}]}']
# -----------------------------------

# %%
df.nunique()
# Out:
# uniq_id                                        10000
# product_name                                    9964
# manufacturer                                    2651
# price                                           2625
# number_available_in_stock                         89
# number_of_reviews                                194
# number_of_answered_questions                      19
# average_review_rating                             19
# amazon_category_and_sub_category                 255
# customers_who_bought_this_item_also_bought      8755
# description                                     8514
# product_information                             9939
# product_description                             8514
# items_customers_buy_after_viewing_this_item     6749
# customer_questions_and_answers                   910
# customer_reviews                                9901
# sellers                                         6581
# dtype: int64

# %% [markdown]
# ### Kiểm tra và xử lí dữ liệu khuyết

# %%
df.isnull().sum()
# Out:
# uniq_id                                           0
# product_name                                      0
# manufacturer                                      7
# price                                          1435
# number_available_in_stock                      2500
# number_of_reviews                                18
# number_of_answered_questions                    765
# average_review_rating                            18
# amazon_category_and_sub_category                690
# customers_who_bought_this_item_also_bought     1062
# description                                     651
# product_information                              58
# product_description                             651
# items_customers_buy_after_viewing_this_item    3065
# customer_questions_and_answers                 9086
# customer_reviews                                 21
# sellers                                        3082
# dtype: int64

# %%
df[df['manufacturer'].isnull() == True] # những dòng mà cột manufacturer bị null
# Out:
#                                uniq_id  \
# 1307  7acd16900b9cb4f8c1988c2cb823becd
# 1592  e7994dbee9b6fdb454488724bef2f7e2
# 4466  1eb8f654c5687388b4296890e65c9d7d
# 4834  da874101badfa98ab3c76548111cfb13
# 5561  a73496640ea6da23dcb49c3b71e05cef
# 9445  a4f4cdbf12552a95083352dd9e4abf1b
# 9628  7ed9421489b9763792060164f39444e8
#
#                                            product_name manufacturer   price  \
# 1307           Trendy Bead Tattoos (Packaging May Vary)          NaN     NaN
# 1592       3D Butterfly Stickers Fly - Assorted Colours          NaN   £2.14
# 4466             GREEN SEA TURTLE Plush Soft Toy - 32cm          NaN  £10.99
# 4834  Disney FROZEN Enchanted Moments Sticker Collec...          NaN  £45.59
# 5561  Match Attax 2014/2015 Liverpool 17 Base 14/15 ...          NaN   £3.54
# 9445  Gibsons Pass the Pud Family Game with AmazonBa...          NaN  £21.71
# 9628          Assortment of Hama Multi beads Pale x1000          NaN     NaN
#
#      number_available_in_stock number_of_reviews  \
# 1307                       NaN                 1
# 1592                     5 new                 2
# 4466                     3 new                12
# 4834                     2 new                 2
# 5561                     6 new                 4
# 9445                       NaN               202
# 9628                     1 new                 1
#
#       number_of_answered_questions average_review_rating  \
# 1307                          11.0    5.0 out of 5 stars
# 1592                           4.0    5.0 out of 5 stars
# 4466                           1.0    4.8 out of 5 stars
# 4834                           2.0    4.0 out of 5 stars
# 5561                           1.0    4.8 out of 5 stars
# 9445                           4.0    4.0 out of 5 stars
# 9628                           NaN    5.0 out of 5 stars
#
#                        amazon_category_and_sub_category  \
# 1307                                                NaN
# 1592                   Arts & Crafts > Paper & Stickers
# 4466                                                NaN
# 4834  Hobbies > Trading Cards & Accessories > Sticke...
# 5561  Hobbies > Trading Cards & Accessories > Packs ...
# 9445                                                NaN
# 9628  Arts & Crafts > Children's Craft Kits > Bead A...
#
#              customers_who_bought_this_item_also_bought  \
# 1307  http://www.amazon.co.uk/Style-Chalk-Multi-Crea...
# 1592  http://www.amazon.co.uk/Peterkin-Butterflies |...
# 4466  http://www.amazon.co.uk/National-Geographic | ...
# 4834  http://www.amazon.co.uk/Disney-Frozen-enchante...
# 5561  http://www.amazon.co.uk/Match-Attax-2014-Liver...
# 9445  http://www.amazon.co.uk/Gibsons-Games-62469-Pa...
# 9628  http://www.amazon.co.uk/Hama-Beads-Neon-Colour...
#
#                                             description  \
# 1307                                Trendy Bead Tattoos
# 1592                                                NaN
# 4466  Cute and cuddly green turtle soft toy. Attenti...
# 4834                                                NaN
# 5561                                                NaN
# 9445                                                NaN
# 9628  Assortment of Hama beads (beads to iron).Instr...
#
#                                     product_information  \
# 1307                                                NaN
# 1592  Technical Details Manufacturer recommended age...
# 4466  Technical Details Item Weight200 g Product Dim...
# 4834  Technical Details    Additional Information AS...
# 5561  Technical Details Item Weight9 g Product Dimen...
# 9445  Technical Details    Additional Information AS...
# 9628  Technical Details Item Weight68 g Manufacturer...
#
#                                     product_description  \
# 1307                                Trendy Bead Tattoos
# 1592                                                NaN
# 4466  Cute and cuddly green turtle soft toy. Attenti...
# 4834                                                NaN
# 5561                                                NaN
# 9445                                                NaN
# 9628  Assortment of Hama beads (beads to iron).Instr...
#
#             items_customers_buy_after_viewing_this_item  \
# 1307  http://www.amazon.co.uk/Style-me-up-53706-Tatt...
# 1592                                                NaN
# 4466  http://www.amazon.co.uk/Melissa-Doug-Sea-Turtl...
# 4834  http://www.amazon.co.uk/packets-Panini-Enchant...
# 5561                                                NaN
# 9445  http://www.amazon.co.uk/Gibsons-Games-62469-Pa...
# 9628  http://www.amazon.co.uk/Hama-Beads-Pastel-Colo...
#
#                          customer_questions_and_answers  \
# 1307                                                NaN
# 1592                                                NaN
# 4466                                                NaN
# 4834                                                NaN
# 5561     Do you get 100 club for free // No 100 club...
# 9445  Could you adapt the gameplay for 3 players, or...
# 9628                                                NaN
#
#                                        customer_reviews  \
# 1307  Would recommend. // 5.0 // 28 Jan. 2015 // By\...
# 1592  beautiful // 5.0 // 15 Aug. 2012 // By\n    \n...
# 4466  A great present! // 5.0 // 15 Nov. 2013 // By\...
# 4834  Five Stars // 5.0 // 30 Dec. 2014 // By\n    \...
# 5561  Four Stars // 4.0 // 21 Jan. 2015 // By\n    \...
# 9445  Perfect after-Christmas Dinner game // 5.0 // ...
# 9628  Five Stars // 5.0 // 10 Feb. 2015 // By\n    \...
#
#                                                 sellers
# 1307  {"seller"=>[{"Seller_name_1"=>"Innovation Home...
# 1592  {"seller"=>[{"Seller_name_1"=>"The Online Stor...
# 4466  {"seller"=>[{"Seller_name_1"=>"Blyme", "Seller...
# 4834                                                NaN
# 5561  {"seller"=>[{"Seller_name_1"=>"Football Card S...
# 9445  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...
# 9628                                                NaN

# %%
df['manufacturer'].fillna('Unknown', inplace = True) # điền 'unknown' vào chỗ khuyết
# Out:
# <ipython-input-103-a20c17e3e50c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['manufacturer'].fillna('Unknown', inplace = True)

# %%
def clean_price(value): # Chuẩn hóa biến price về dạng float
    if pd.isna(value) or isinstance(value, (float, int)):
        return value

    value = value.replace('£', '').replace(',', '')
    if '-' in value:
        low, high = value.split(' - ')
        return (float(low) + float(high)) / 2
    return float(value)

df['price'] = df['price'].apply(clean_price)
df['price'].fillna(df['price'].mean(), inplace = True) # diền khuyết bằng giá trị trung bình
# Out:
# <ipython-input-104-9921fbc38d30>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(df['price'].mean(), inplace = True)

# %%
# In 10 dòng đầu của cột number_available_in_stock bị khuyết
df[df['number_available_in_stock'].isna()].head(10)
# Out:
#                              uniq_id  \
# 1   b17540ef7e86e461d37f3ae58b7b72ac
# 3   e12b92dbb8eaee78b22965d2a9bbbd9f
# 4   e33a9adeed5f36840ccc227db4682a36
# 5   cb34f0a84102c1ebc3ef6892d7444d36
# 6   f74b562470571dfb689324adf236f82c
# 11  878048c41f3c249badb3704e160b4c6e
# 20  4aaa27925929708a6b56fd7e46b35208
# 22  26de90be8191b92ea208c2111c7090cd
# 24  1b3d6d9f9c79db8c54c0c2cbb50de1cf
# 29  8a9af1fc5f227191c00447b0c44f7700
#
#                                          product_name manufacturer   price  \
# 1   FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys   16.99
# 3      HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby   39.99
# 4   Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby   32.19
# 5   20pcs Model Garden Light Double Heads Lamppost...      Generic    6.99
# 6   Hornby 00 Gauge 230mm BR Bogie Passenger Brake...       Hornby   24.99
# 11  Kato (USA) 176-1308 F3B Denver & Rio Grande We...   Kato (USA)  273.60
# 20   Preiser 30495 Horse Drawn Wedding Coach (Closed)      Preiser   27.55
# 22  Bachmann Class A2 60534 'Irish Elegance' BR Li...     Bachmann  149.92
# 24             Roco 64723 OBB Railjet Economy Coach V         Roco   49.95
# 29  Gaugemaster HBYS Hornby Type Colour Light Sign...  Gaugemaster    5.95
#
#    number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 1                        NaN                 2                           1.0
# 3                        NaN                 1                           2.0
# 4                        NaN                 3                           2.0
# 5                        NaN                 2                           1.0
# 6                        NaN                 2                           1.0
# 11                       NaN                 1                           1.0
# 20                       NaN                 1                           1.0
# 22                       NaN                 1                           1.0
# 24                       NaN                 1                           1.0
# 29                       NaN                 5                           1.0
#
#    average_review_rating                   amazon_category_and_sub_category  \
# 1     4.5 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 3     5.0 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 4     4.7 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 5     5.0 out of 5 stars  Hobbies > Model Trains & Railway Sets > Lighti...
# 6     4.5 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 11    5.0 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 20    5.0 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 22    5.0 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 24    5.0 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 29    4.8 out of 5 stars  Hobbies > Model Trains & Railway Sets > Lighti...
#
#            customers_who_bought_this_item_also_bought  \
# 1   http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 3                                                 NaN
# 4   http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
# 5   http://www.amazon.co.uk/Single-Head-Garden-Lig...
# 6   http://www.amazon.co.uk/Hornby-R4388-RailRoad-...
# 11                                                NaN
# 20  http://www.amazon.co.uk/Preiser-14415-Wedding-...
# 22  http://www.amazon.co.uk/Hornby-R3060-RailRoad-...
# 24                                                NaN
# 29  http://www.amazon.co.uk/Hornby-R8952-Skaledale...
#
#                                           description  \
# 1   Size Name:Large FunkyBuys® Large Christmas Hol...
# 3   Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4   Product Description Hornby RailRoad 0-4-0 Gild...
# 5   These delicate model garden lights are mainly ...
# 6   Product Description Hornby BR bogie passenger ...
# 11       Suitable for the following scale(s): N Scale
# 20      Suitable for the following scale(s): HO Scale
# 22      Suitable for the following scale(s): OO Scale
# 24      Suitable for the following scale(s): HO Scale
# 29  Suitable for the following scale(s): OO Scalec...
#
#                                   product_information  \
# 1   Technical Details Manufacturer recommended age...
# 3   Technical Details Item Weight259 g Product Dim...
# 4   Technical Details Item Weight159 g Product Dim...
# 5   Technical Details Manufacturer recommended age...
# 6   Technical Details Item Weight222 g Product Dim...
# 11  Technical Details Manufacturer recommended age...
# 20  Technical Details Item Weight9 g Product Dimen...
# 22  Technical Details Manufacturer recommended age...
# 24  Technical Details Manufacturer recommended age...
# 29  Technical Details Manufacturer recommended age...
#
#                                   product_description  \
# 1   Size Name:Large FunkyBuys® Large Christmas Hol...
# 3   Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4   Product Description Hornby RailRoad 0-4-0 Gild...
# 5   These delicate model garden lights are mainly ...
# 6   Product Description Hornby BR bogie passenger ...
# 11       Suitable for the following scale(s): N Scale
# 20      Suitable for the following scale(s): HO Scale
# 22      Suitable for the following scale(s): OO Scale
# 24      Suitable for the following scale(s): HO Scale
# 29  Suitable for the following scale(s): OO Scalec...
#
#           items_customers_buy_after_viewing_this_item  \
# 1   http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 3                                                 NaN
# 4   http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
# 5   http://www.amazon.co.uk/Single-Head-Garden-Lig...
# 6                                                 NaN
# 11                                                NaN
# 20                                                NaN
# 22                                                NaN
# 24                                                NaN
# 29  http://www.amazon.co.uk/model-railway-signal-l...
#
#                        customer_questions_and_answers  \
# 1   can you turn off sounds // hi no you cant turn...
# 3                                                 NaN
# 4                                                 NaN
# 5   is it possible to replace thr grain of wheat l...
# 6                                                 NaN
# 11                                                NaN
# 20                                                NaN
# 22                                                NaN
# 24                                                NaN
# 29                                                NaN
#
#                                      customer_reviews  \
# 1   Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 3   I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4   Birthday present // 5.0 // 14 April 2014 // By...
# 5   Five Stars // 5.0 // 27 Dec. 2014 // By\n    \...
# 6   High standard model, well worth the wait. Repl...
# 11  Five Stars // 5.0 // 12 Nov. 2014 // By\n    \...
# 20  An excellent HO scale diorama piece // 5.0 // ...
# 22  Five Stars // 5.0 // 8 Jun. 2015 // By\n    \n...
# 24  Excellent model in perfect condition from repu...
# 29  Five Stars // 5.0 // 28 Sept. 2015 // By\n    ...
#
#                                               sellers
# 1   {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...
# 3                                                 NaN
# 4                                                 NaN
# 5   {"seller"=>{"Seller_name_1"=>"STK e-Shop", "Se...
# 6   {"seller"=>{"Seller_name_1"=>"MyHobbyStore Ret...
# 11  {"seller"=>{"Seller_name_1"=>"kirara-ya", "Sel...
# 20  {"seller"=>{"Seller_name_1"=>"Au Pullman", "Se...
# 22  {"seller"=>{"Seller_name_1"=>"MyHobbyStore Ret...
# 24  {"seller"=>{"Seller_name_1"=>"Gaugemaster", "S...
# 29                                                NaN

# %%
# Điền khuyết cột number_available_in_stock bằng giá trị 0
df['number_available_in_stock'].fillna(0, inplace = True)
# Out:
# <ipython-input-106-ba6339c938e2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['number_available_in_stock'].fillna(0, inplace = True)

# %%
# điền khuyết cột number_of_reviews băng 0, chuyển về dạng số thực
df['number_of_reviews'] = pd.to_numeric(df['number_of_reviews'], errors='coerce')
df['number_of_reviews'].fillna( 0, inplace = True)
df['number_of_reviews'] = df['number_of_reviews'].astype(float)
# Out:
# <ipython-input-31-d8f4fff13bf4>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['number_of_reviews'].fillna( 0, inplace = True)

# %%
df[df['number_of_answered_questions'].isna()].head()
df['number_of_answered_questions'].fillna(0, inplace = True)
# Out:
# <ipython-input-109-9fba3aa5ea8d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['number_of_answered_questions'].fillna(0, inplace = True)

# %%
def extract_rating(text):
  if pd.isna(text):
    return text
  else:
    temp = text.split(' ')[0]
  return float(temp)

df['average_review_rating'] = df['average_review_rating'].apply(extract_rating)
df['average_review_rating'].fillna(df['average_review_rating'].mean(), inplace = True)
# Out:
# <ipython-input-110-a85dd1615428>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['average_review_rating'].fillna(df['average_review_rating'].mean(), inplace = True)

# %%
df['amazon_category_and_sub_category'].fillna('unknown', inplace = True)
df['customers_who_bought_this_item_also_bought'].fillna('unknown', inplace = True)
df['description'].fillna('unknown', inplace = True)
df['product_information'].fillna('unknown', inplace = True)
df['product_description'].fillna('unknown', inplace = True)
df['items_customers_buy_after_viewing_this_item'].fillna('unknown', inplace = True)
df['customer_questions_and_answers'].fillna('unknown', inplace = True)
df['customer_reviews'].fillna('unknown', inplace = True)
df['sellers'].fillna('unknown', inplace = True)
# Out:
# <ipython-input-111-c51b6c34212c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['amazon_category_and_sub_category'].fillna('unknown', inplace = True)
# <ipython-input-111-c51b6c34212c>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['customers_who_bought_this_item_also_bought'].fillna('unknown', inplace = True)
# <ipython-input-111-c51b6c34212c>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['description'].fillna('unknown', inplace = True)
# <ipython-input-111-c51b6c34212c>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['product_information'].fillna('unknown', inplace = True)
# <ipython-input-111-c51b6c34212c>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['product_description'].fillna('unknown', inplace = True)
# <ipython-input-111-c51b6c34212c>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['items_customers_buy_after_viewing_this_item'].fillna('unknown', inplace = True)
# <ipython-input-111-c51b6c34212c>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['customer_questions_and_answers'].fillna('unknown', inplace = True)
# <ipython-input-111-c51b6c34212c>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['customer_reviews'].fillna('unknown', inplace = True)
# <ipython-input-111-c51b6c34212c>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sellers'].fillna('unknown', inplace = True)

# %%
df.isna().sum()
# Out:
# uniq_id                                        0
# product_name                                   0
# manufacturer                                   0
# price                                          0
# number_available_in_stock                      0
# number_of_reviews                              0
# number_of_answered_questions                   0
# average_review_rating                          0
# amazon_category_and_sub_category               0
# customers_who_bought_this_item_also_bought     0
# description                                    0
# product_information                            0
# product_description                            0
# items_customers_buy_after_viewing_this_item    0
# customer_questions_and_answers                 0
# customer_reviews                               0
# sellers                                        0
# dtype: int64

# %%
#Lưu data đã làm sạch
#df.to_csv("/content/drive/MyDrive/Course DA/Final Project/cleaned_data.csv", index = False)

# %%
df = pd.read_csv("/content/drive/MyDrive/Course DA/Final Project/cleaned_data.csv")
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer  price  \
# 0                              Hornby 2014 Catalogue       Hornby   3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  32.19
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                         0                 2                           1.0
# 2                     2 new                17                           2.0
# 3                         0                 1                           2.0
# 4                         0                 3                           2.0
#
#    average_review_rating                   amazon_category_and_sub_category  \
# 0                    4.9  Hobbies > Model Trains & Railway Sets > Rail V...
# 1                    4.5  Hobbies > Model Trains & Railway Sets > Rail V...
# 2                    3.9  Hobbies > Model Trains & Railway Sets > Rail V...
# 3                    5.0  Hobbies > Model Trains & Railway Sets > Rail V...
# 4                    4.7  Hobbies > Model Trains & Railway Sets > Rail V...
#
#           customers_who_bought_this_item_also_bought  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                                            unknown
# 4  http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
#
#                                          description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
# 1  Technical Details Manufacturer recommended age...
# 2  Technical Details Manufacturer recommended age...
# 3  Technical Details Item Weight259 g Product Dim...
# 4  Technical Details Item Weight159 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                            unknown
# 4  http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
# 1  can you turn off sounds // hi no you cant turn...
# 2  What is the gauge of the track // Hi Paul.Trut...
# 3                                            unknown
# 4                                            unknown
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3  I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4  Birthday present // 5.0 // 14 April 2014 // By...
#
#                                              sellers
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...
# 3                                            unknown
# 4                                            unknown

# %% [markdown]
# ### Kiểm tra dữ liệu bị lăp và xóa

# %%
df[df.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [uniq_id, product_name, manufacturer, price, number_available_in_stock, number_of_reviews, number_of_answered_questions, average_review_rating, amazon_category_and_sub_category, customers_who_bought_this_item_also_bought, description, product_information, product_description, items_customers_buy_after_viewing_this_item, customer_questions_and_answers, customer_reviews, sellers]
# Index: []

# %%
# memove duplicate row and keep last
df.drop_duplicates(keep = 'last', inplace = True)

# %%
df.drop(['description'], axis = 1, inplace = True)

# %% [markdown]
# ### Bảng Normalize Data

# %%
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer  price  \
# 0                              Hornby 2014 Catalogue       Hornby   3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  32.19
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                         0                 2                           1.0
# 2                     2 new                17                           2.0
# 3                         0                 1                           2.0
# 4                         0                 3                           2.0
#
#    average_review_rating                   amazon_category_and_sub_category  \
# 0                    4.9  Hobbies > Model Trains & Railway Sets > Rail V...
# 1                    4.5  Hobbies > Model Trains & Railway Sets > Rail V...
# 2                    3.9  Hobbies > Model Trains & Railway Sets > Rail V...
# 3                    5.0  Hobbies > Model Trains & Railway Sets > Rail V...
# 4                    4.7  Hobbies > Model Trains & Railway Sets > Rail V...
#
#           customers_who_bought_this_item_also_bought  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                                            unknown
# 4  http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
# 1  Technical Details Manufacturer recommended age...
# 2  Technical Details Manufacturer recommended age...
# 3  Technical Details Item Weight259 g Product Dim...
# 4  Technical Details Item Weight159 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                            unknown
# 4  http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
# 1  can you turn off sounds // hi no you cant turn...
# 2  What is the gauge of the track // Hi Paul.Trut...
# 3                                            unknown
# 4                                            unknown
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3  I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4  Birthday present // 5.0 // 14 April 2014 // By...
#
#                                              sellers
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...
# 3                                            unknown
# 4                                            unknown

# %%
df['number_available_in_stock'].value_counts()
# Out:
# number_available_in_stock
# 0                2500
# 2 new            1337
# 3 new             981
# 4 new             753
# 5 new             590
# 6 new             475
# 1 new             403
# 7 new             371
# 8 new             292
# 9 new             207
# 10 new            204
# 11 new            180
# 12 new            160
# 13 new            121
# 15 new            120
# 14 new            112
# 16 new            106
# 1 used             89
# 17 new             81
# 18 new             80
# 19 new             73
# 21 new             58
# 22 new             53
# 20 new             51
# 23 new             45
# 24 new             35
# 28 new             35
# 30 new             34
# 25 new             33
# 26 new             32
# 27 new             31
# 35 new             28
# 32 new             28
# 29 new             27
# 2 used             21
# 31 new             21
# 3 used             18
# 38 new             16
# 33 new             16
# 34 new             15
# 36 new             13
# 37 new             12
# 1 collectible      12
# 4 used             10
# 39 new              8
# 40 new              7
# 47 new              6
# 8 used              6
# 42 new              6
# 41 new              5
# 46 new              5
# 56 new              5
# 43 new              5
# 14 used             4
# 49 new              4
# 6 used              4
# 59 new              3
# 48 new              3
# 51 new              3
# 73 new              3
# 44 new              3
# 7 used              3
# 57 new              2
# 58 new              2
# 5 used              2
# 69 new              2
# 54 new              2
# 45 new              2
# 50 new              2
# 10 used             2
# 60 new              2
# 1 refurbished       2
# 66 new              1
# 62 new              1
# 70 new              1
# 2 collectible       1
# 12 used             1
# 52 new              1
# 72 new              1
# 71 new              1
# 64 new              1
# 53 new              1
# 55 new              1
# 78 new              1
# 63 new              1
# 74 new              1
# 65 new              1
# 92 new              1
# 86 new              1
# 9 used              1
# Name: count, dtype: int64

# %%
# Tạch cột
def number_available_in_stock(x):
  if x == '0':
    return 0, "0"
  else:
    match = re.match(r'(\d+)\s*(\w+)', x)
    if match:
        number = int(match.group(1))
        attribute = match.group(2)
    return number, attribute

# %%
df[['number_available_in_stock', 'product_state_in_stock']] = df['number_available_in_stock'] \
    .apply(number_available_in_stock).apply(pd.Series)

# %%
#check value in amazon_category_and_sub_category column
df['amazon_category_and_sub_category'].value_counts()
# Out:
# amazon_category_and_sub_category
# Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models > Vehicles                                             880
# unknown                                                                                                                     690
# Figures & Playsets > Science Fiction & Fantasy                                                                              485
# Arts & Crafts > Children's Craft Kits > Bead Art & Jewellery-Making                                                         368
# Characters & Brands > Disney > Toys                                                                                         347
# Hobbies > Trading Cards & Accessories > Packs & Sets                                                                        317
# Games > Dice & Dice Games                                                                                                   298
# Party Supplies > Decorations > Balloons                                                                                     293
# Party Supplies > Banners, Stickers & Confetti > Banners                                                                     278
# Games > Card Games                                                                                                          242
# Puppets & Puppet Theatres > Hand Puppets                                                                                    241
# Characters & Brands > Star Wars > Toys                                                                                      213
# Figures & Playsets > Accessories                                                                                            191
# Fancy Dress > Accessories > Masks                                                                                           188
# Dolls & Accessories > Dolls' House Dolls & Accessories > Dolls' House Accessories                                           172
# Hobbies > Model Trains & Railway Sets > Rail Vehicles > Trains                                                              170
# Fancy Dress > Costumes > Adults                                                                                             169
# Dolls & Accessories > Soft Dolls                                                                                            151
# Jigsaws & Puzzles > Jigsaws                                                                                                 149
# Arts & Crafts > Paper & Stickers                                                                                            148
# Figures & Playsets > Knights & Castles                                                                                      148
# Sports Toys & Outdoor > Kites & Flight Toys                                                                                 141
# Hobbies > Model Building Kits > Tanks                                                                                       140
# Fancy Dress > Accessories > Temporary Tattoos                                                                               138
# Characters & Brands > Hasbro                                                                                                137
# Hobbies > Remote Controlled Devices > Parts & Accessories                                                                   130
# Die-Cast & Toy Vehicles > Toy Trains & Accessories > Toy Trains & Sets                                                      114
# Games > Educational Games                                                                                                   113
# Figures & Playsets > Pirates                                                                                                104
# Hobbies > Slot Cars, Race Tracks & Accessories > Slot Cars                                                                  103
# Hobbies > Model Trains & Railway Sets > Rail Vehicles > Locomotives                                                          88
# Games > Chess                                                                                                                86
# Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Toy Cars & Trucks                                                     86
# Games > Dominoes & Tile Games                                                                                                84
# Figures & Playsets > Dinosaurs                                                                                               82
# Jigsaws & Puzzles > Brain Teasers                                                                                            78
# Sports Toys & Outdoor > Beach Toys > Paddling Pools                                                                          77
# Arts & Crafts > Colouring Pens & Markers                                                                                     75
# Games > Trivia & Quiz Games                                                                                                  69
# Arts & Crafts > Art Sand                                                                                                     69
# Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models                                                         67
# Hobbies > Collectible Figures & Memorabilia > Bobbleheads & Busts                                                            65
# Hobbies > Remote Controlled Devices > Helicopters & Quadcopters                                                              61
# Arts & Crafts > Children's Craft Kits                                                                                        58
# Fancy Dress > Accessories > Sets & Kits                                                                                      56
# Hobbies > Slot Cars, Race Tracks & Accessories > Race Tracks                                                                 51
# Hobbies > Collectible Figures & Memorabilia > Collectible Figures & Accessories                                              47
# Jigsaws & Puzzles > 3-D Puzzles                                                                                              45
# Characters & Brands > Tomy                                                                                                   44
# Pretend Play > Shops & Accessories                                                                                           44
# Hobbies > Model Trains & Railway Sets > Accessories > Figures & Decoration Parts > Figures                                   43
# Characters & Brands > Ravensburger                                                                                           43
# Arts & Crafts > Colouring Pencils                                                                                            41
# Sports Toys & Outdoor > Beach Toys > Flotation Devices & Accessories                                                         38
# Baby & Toddler Toys > Sorting, Stacking & Plugging Toys                                                                      37
# Characters & Brands > Harry Potter > Toys                                                                                    35
# Characters & Brands > Crayola                                                                                                34
# Figures & Playsets > Cowboys & Indians                                                                                       34
# Party Supplies > Banners, Stickers & Confetti > Garlands                                                                     34
# Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Friction Cars                                                         33
# Party Supplies > Invitations                                                                                                 32
# Hobbies > Trading Cards & Accessories > Storage Albums & Cases > Sleeves                                                     32
# Figures & Playsets > Farm & Animals                                                                                          32
# Sports Toys & Outdoor > Beach Toys > Water Pistols                                                                           29
# Hobbies > Slot Cars, Race Tracks & Accessories > Service & Tuning Parts                                                      29
# Hobbies > Model Trains & Railway Sets > Accessories > Landscaping > Track Construction                                       28
# Puppets & Puppet Theatres > Finger Puppets                                                                                   27
# Baby & Toddler Toys > Spinning Tops                                                                                          27
# Hobbies > Collectible Figures & Memorabilia > Collectible Props & Memorabilia                                                27
# Dolls & Accessories > Dolls' House Dolls & Accessories > Dolls' House Furniture                                              26
# Sports Toys & Outdoor > Garden Tools                                                                                         24
# Figures & Playsets > Military                                                                                                21
# Arts & Crafts > Painting By Numbers                                                                                          19
# Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models > Boats                                                 18
# Baby & Toddler Toys > Rocking Horses                                                                                         17
# Sports Toys & Outdoor > Beach Toys > Water Play Tables                                                                       16
# Party Supplies > Banners, Stickers & Confetti > Streamers                                                                    16
# Arts & Crafts > Blackboards                                                                                                  15
# Characters & Brands > VTech                                                                                                  15
# Dolls & Accessories > Playsets                                                                                               15
# Party Supplies > Decorations > Cake Decorations                                                                              15
# Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Signal & Sound                                       13
# Characters & Brands > Toy Story > Toys                                                                                       12
# Games > DVD Games                                                                                                            12
# Baby & Toddler Toys > Sound Toys                                                                                             12
# Sports Toys & Outdoor > Beach Toys > Beach Toys                                                                              12
# Hobbies > Model Building Kits > Accessories                                                                                  11
# Fancy Dress > Accessories                                                                                                    11
# Figures & Playsets > Sport                                                                                                   11
# Sports Toys & Outdoor > Darts & Accessories                                                                                  11
# Hobbies > Trading Cards & Accessories > Single Cards                                                                         10
# Fancy Dress > Costumes                                                                                                       10
# Sports Toys & Outdoor > Beach Toys > Airbeds & Inflating Devices                                                             10
# Hobbies > Model Trains & Railway Sets > Accessories > Landscaping > Road Construction                                        10
# Novelty & Special Use > Novelty > Accessories > Buttons & Pins                                                               10
# Games > Board Games                                                                                                           9
# Characters & Brands > Action Man                                                                                              9
# Hobbies > Remote Controlled Devices > Robots                                                                                  9
# Hobbies > Trading Cards & Accessories > Storage Albums & Cases > Albums                                                       9
# Party Supplies > Decorations > Props                                                                                          9
# Hobbies > Model Building Kits > Steam Engines                                                                                 9
# Musical Toy Instruments > Guitars & Strings                                                                                   8
# Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Lamps & Lighting                                      8
# Party Supplies > Party Favours                                                                                                8
# Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models > Aircraft                                               8
# Fancy Dress > Costumes > Kids & Toddlers                                                                                      8
# Die-Cast & Toy Vehicles > Toy Vehicle Playsets                                                                                7
# Characters & Brands > Thunderbirds > Toys                                                                                     7
# Characters & Brands > Barbie                                                                                                  7
# Party Supplies > Banners, Stickers & Confetti > Confetti                                                                      7
# Musical Toy Instruments > Wind & Brass                                                                                        7
# Characters & Brands > Thomas & Friends > Train Play > Wooden Thomas                                                           7
# Hobbies > Trading Cards & Accessories > Sticker Collections                                                                   6
# Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models > Trains                                                 6
# Hobbies > Model Trains & Railway Sets > Rail Vehicles > Wagons                                                                6
# Baby & Toddler Toys > Rattles                                                                                                 5
# Characters & Brands > Ravensburger > Children's Puzzles                                                                       5
# Characters & Brands > Early Learning Centre                                                                                   5
# Hobbies > Model Trains & Railway Sets > Accessories > Recreational Activities                                                 5
# Hobbies > Model Trains & Railway Sets > Accessories > Landscaping > Landscape Architecture                                    4
# Musical Toy Instruments > Pianos & Keyboards                                                                                  4
# Characters & Brands > Ravensburger > Games                                                                                    4
# Hobbies > Model Building Kits                                                                                                 4
# Bags > Schoolbags & Backpacks > Bags                                                                                          4
# Characters & Brands > Bob the Builder > Toys                                                                                  4
# Games > Casino Equipment > Game Sets > Poker Sets                                                                             4
# Sports Toys & Outdoor > Climbing Frames                                                                                       4
# Characters & Brands > WWE                                                                                                     4
# Office Supplies > Desk Accessories & Storage Products > Desk Supplies Organisers & Dispensers > Desk Supplies Organisers      4
# Characters & Brands > Action Man > Toys                                                                                       4
# Characters & Brands > Barbie > Barbie Dolls & Accessories                                                                     4
# Worlds Apart > Kid Venture > Kites                                                                                            3
# Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Control Moduls                                        3
# Hobbies > Model Building Kits > Boats & Watercraft                                                                            3
# Fancy Dress > Accessories > Capes & Wings                                                                                     3
# Home Accessories > Decorative Accessories > Stickers > Window Stickers                                                        3
# Characters & Brands > Thomas & Friends > Ages 3-4 Years                                                                       3
# Sports Toys & Outdoor > Bikes, Trikes & Ride-ons                                                                              3
# Games > Casino Equipment > Game Tables > Poker Tables                                                                         3
# Hobbies > Remote Controlled Devices > Tanks                                                                                   3
# Hobbies > Model Trains & Railway Sets > Starter Packs & Sets                                                                  3
# Hobbies > Model Building Kits > Cars & Vehicles                                                                               3
# Hobbies > Model Building Kits > Figures                                                                                       3
# Games > Casino Equipment > Bingo Equipment                                                                                    3
# Games > Casino Equipment > Game Sets > Blackjack Sets                                                                         3
# Arts & Crafts > Children's Chalk                                                                                              3
# Games > Casino Equipment > Game Layouts > Poker Layouts                                                                       2
# Hobbies > Model Trains & Railway Sets > Accessories > Landscaping                                                             2
# Office Supplies > Labels, Index Dividers & Stamps > Labels & Stickers                                                         2
# Gardening > Hand Tools > Gardening Trowels                                                                                    2
# Games > Tabletop & Miniature Gaming                                                                                           2
# Games > Casino Equipment > Poker Chips                                                                                        2
# Pens, Pencils & Writing Supplies > Erasers & Correction Supplies > Erasers                                                    2
# Dogs > Clothing & Accessories > Costumes                                                                                      2
# Games > Casino Equipment > Poker Chip Cases & Trays > Cases                                                                   2
# Characters & Brands > Thomas & Friends > Train Play > Take Along Thomas                                                       2
# Sports Toys & Outdoor > Bikes, Trikes & Ride-ons > Children's Bikes                                                           2
# Dolls & Accessories > Fashion Dolls & Accessories                                                                             2
# Baby & Toddler Toys > Rockers & Ride-ons                                                                                      2
# Characters & Brands > Thomas & Friends > Train Play > Motor Road & Rail                                                       2
# Educational Toys > Mathematics                                                                                                2
# Baby & Toddler Toys > Pushchair Toys                                                                                          2
# Dolls & Accessories > Fashion Dolls & Accessories > Houses                                                                    2
# Baby & Toddler Toys > Teaching Clocks                                                                                         2
# Supporters' Gear > Football > Memorabilia & Collectibles                                                                      2
# Fancy Dress > Accessories > Hats                                                                                              2
# Figures & Playsets > Emergency Services                                                                                       2
# Characters & Brands > BRIO > BRIO Wooden Roadway System                                                                       2
# Characters & Brands > LeapFrog                                                                                                2
# Electronic Toys > Kids Remote & App Controlled Toys                                                                           2
# Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Rockets & Spaceships                                                   2
# Hobbies > Trading Cards & Accessories > Storage Albums & Cases > Cases                                                        2
# Educational Toys > Literacy & Spelling                                                                                        1
# Games > Mystery Games                                                                                                         1
# Games > Travel & Pocket Games                                                                                                 1
# Characters & Brands > Hornby                                                                                                  1
# Characters & Brands > LeapFrog > LeapPad Learning System                                                                      1
# Games > Strategy Games                                                                                                        1
# Novelty Jewellery > Charms > Bead Charms                                                                                      1
# Dolls & Accessories > Dolls' House Dolls & Accessories > Dolls' Houses                                                        1
# Dolls & Accessories > Fashion Dolls & Accessories > Fashion Dolls                                                             1
# Puppets & Puppet Theatres > Accessories                                                                                       1
# Women > Tops & T-Shirts                                                                                                       1
# Jigsaws & Puzzles > Jigsaw Accessories                                                                                        1
# Electronic Toys > Educational Computers & Accessories                                                                         1
# Cooking & Dining > Kitchen Tools & Gadgets > Barware > Straws                                                                 1
# Dolls & Accessories > Fashion Dolls & Accessories > Vehicles                                                                  1
# Party Supplies > Party Bags                                                                                                   1
# Sports Toys & Outdoor > Cup & Ball Games                                                                                      1
# Characters & Brands > Upstarts > Family Games                                                                                 1
# Lab & Scientific Products > Lab Instruments & Equipment > Microscopes & Equipment > Microscopes                               1
# Gardening > Greenhouses & Plant Germination Equipment > Greenhouses                                                           1
# Cooking & Dining > Kitchen Tools & Gadgets > Barware > Glass Markers & Charms                                                 1
# Sports Toys & Outdoor > Target Games                                                                                          1
# Sports Toys & Outdoor > Racket Games                                                                                          1
# Arts & Crafts > Children's Craft Kits > Children's Knitting & Textile Design                                                  1
# Sports Toys & Outdoor > Bikes, Trikes & Ride-ons > Push Power Ride-ons & Accessories > Push Power Ride-ons                    1
# Medication & Remedies > Alternative Medicine                                                                                  1
# Baby & Toddler Toys > Learning & Activity Toys                                                                                1
# Electronic Toys > Robots                                                                                                      1
# Sweets, Chocolate & Gum > Chocolate > Bars > Multipack Bars                                                                   1
# Characters & Brands > Upstarts > Children's Games                                                                             1
# Novelty & Special Use > Novelty                                                                                               1
# Games > Casino Equipment > Game Sets                                                                                          1
# Jams, Honey & Spreads > Sandwich Spreads, Pates & Pastes                                                                      1
# Laundry, Storage & Organisation > Baskets & Bins > Storage Boxes & Chests > Storage Boxes                                     1
# Electronic Toys > Digital Cameras                                                                                             1
# Characters & Brands > BRIO > BRIO Wooden Railway System                                                                       1
# Figures & Playsets > Transportation & Traffic                                                                                 1
# Characters & Brands > BRIO > BRIO Builder System                                                                              1
# Indoor Lighting > Specialty & Decorative Lighting > Book Lights                                                               1
# Car Parts > Instruments > Nuts & Bolts                                                                                        1
# Hobbies > Slot Cars, Race Tracks & Accessories                                                                                1
# Pens, Pencils & Writing Supplies > Markers & Highlighters > Art Markers                                                       1
# Women > Accessories                                                                                                           1
# Pretend Play > Play Tools                                                                                                     1
# Camping & Hiking > Sleeping Gear > Air Pumps > Hand Pumps                                                                     1
# Arts & Crafts > Doll Making                                                                                                   1
# Home Accessories > Seasonal Décor > Christmas                                                                                 1
# Hobbies > Model Building Kits > Model Building Tools                                                                          1
# Bedding & Linens > Children's Bedding > Sheets & Pillowcases > Flat Sheets                                                    1
# Storage, Cleaning & Ring Sizers > Boxes & Organisers                                                                          1
# Sweets, Chocolate & Gum > Chocolate                                                                                           1
# Arts & Crafts > Art & Craft Supplies > Glitter                                                                                1
# Arts & Crafts > Felt Kits                                                                                                     1
# Handbags & Shoulder Bags > Kids'                                                                                              1
# Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Transformers & Decoders                               1
# Party Supplies > Party Tableware                                                                                              1
# Men > Tops & T-Shirts > T-Shirts                                                                                              1
# Sex & Sensuality > Erotic Clothing > Women's > Costumes                                                                       1
# Pens, Pencils & Writing Supplies > Pens & Refills > Pen Refills                                                               1
# Pens, Pencils & Writing Supplies > Erasers & Correction Supplies > Correction Pens                                            1
# Pens, Pencils & Writing Supplies > Pencils > Coloured Pencils                                                                 1
# Pens, Pencils & Writing Supplies > Markers & Highlighters > Permanent Markers & Marker Pens                                   1
# Arts & Crafts > Drawing & Painting Supplies > Paints > Poster Paints                                                          1
# Home Accessories > Seasonal Décor > Christmas > Novelty Decorations                                                           1
# Cooking & Dining > Kitchen Tools & Gadgets > Barware > Ice Cube Moulds & Trays                                                1
# Medical Supplies & Equipment > Braces, Splints & Slings > Tape & Supplies                                                     1
# Characters & Brands > Winnie-the-Pooh > Toys                                                                                  1
# Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Cable                                                 1
# Characters & Brands > Harry Potter > Books > Stationery                                                                       1
# Games > Casino Equipment > Game Sets > Roulette Sets                                                                          1
# Games > Casino Equipment > Game Layouts > Craps Layouts                                                                       1
# Characters & Brands > Marvin's Magic                                                                                          1
# Hobbies > Trading Cards & Accessories                                                                                         1
# Arts & Crafts > Art & Craft Supplies > Thread > Sewing                                                                        1
# Jigsaws & Puzzles > Frame Jigsaws                                                                                             1
# Medication & Remedies > Pain & Fever > Hot & Cold Therapies                                                                   1
# Sports Toys & Outdoor > Bikes, Trikes & Ride-ons > Scooters                                                                   1
# Baby & Toddler Toys > Activity Centres                                                                                        1
# Indoor Lighting > Specialty & Decorative Lighting                                                                             1
# Hobbies > Model Trains & Railway Sets                                                                                         1
# Cooking & Dining > Kitchen Tools & Gadgets > Barware > Coasters                                                               1
# Women > Accessories > Eyewear & Accessories > Sunglasses                                                                      1
# Hobbies > Model Trains & Railway Sets > Accessories                                                                           1
# Games > Drinking Games                                                                                                        1
# Name: count, dtype: int64

# %%
#Tách cột
categories_split = df['amazon_category_and_sub_category'].str.split('>')

df[['Category', 'Sub_category_1', 'Sub_category_2', 'Sub_category_3', 'Sub_category_4']] = pd.DataFrame(categories_split.tolist(), index=df.index)
df = df.drop(['amazon_category_and_sub_category'], axis = 1)
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer  price  \
# 0                              Hornby 2014 Catalogue       Hornby   3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  32.19
#
#    number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                          5                15                           1.0
# 1                          0                 2                           1.0
# 2                          2                17                           2.0
# 3                          0                 1                           2.0
# 4                          0                 3                           2.0
#
#    average_review_rating         customers_who_bought_this_item_also_bought  \
# 0                    4.9  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1                    4.5  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2                    3.9  http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                    5.0                                            unknown
# 4                    4.7  http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
# 1  Technical Details Manufacturer recommended age...
# 2  Technical Details Manufacturer recommended age...
# 3  Technical Details Item Weight259 g Product Dim...
# 4  Technical Details Item Weight159 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                            unknown
# 4  http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
# 1  can you turn off sounds // hi no you cant turn...
# 2  What is the gauge of the track // Hi Paul.Trut...
# 3                                            unknown
# 4                                            unknown
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3  I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4  Birthday present // 5.0 // 14 April 2014 // By...
#
#                                              sellers product_state_in_stock  \
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...                    new
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...                      0
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...                    new
# 3                                            unknown                      0
# 4                                            unknown                      0
#
#    Category                 Sub_category_1   Sub_category_2 Sub_category_3  \
# 0  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 1  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 2  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 3  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 4  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
#
#   Sub_category_4
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None

# %%
# Điền unknown
df.fillna('unknown', inplace = True)

# %%
# lưu bảng normalized_data
df.to_csv("/content/drive/MyDrive/Course DA/Final Project/mormalized_data.csv", index = False)

# %% [markdown]
# ### Tạo bản review từ customer_reviews trong normalized_data

# %%
df = pd.read_csv("/content/drive/MyDrive/Course DA/Final Project/mormalized_data.csv")
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer  price  \
# 0                              Hornby 2014 Catalogue       Hornby   3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  32.19
#
#    number_available_in_stock  number_of_reviews  number_of_answered_questions  \
# 0                          5               15.0                           1.0
# 1                          0                2.0                           1.0
# 2                          2               17.0                           2.0
# 3                          0                1.0                           2.0
# 4                          0                3.0                           2.0
#
#    average_review_rating         customers_who_bought_this_item_also_bought  \
# 0                    4.9  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1                    4.5  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2                    3.9  http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                    5.0                                            unknown
# 4                    4.7  http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
# 1  Technical Details Manufacturer recommended age...
# 2  Technical Details Manufacturer recommended age...
# 3  Technical Details Item Weight259 g Product Dim...
# 4  Technical Details Item Weight159 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                            unknown
# 4  http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
# 1  can you turn off sounds // hi no you cant turn...
# 2  What is the gauge of the track // Hi Paul.Trut...
# 3                                            unknown
# 4                                            unknown
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3  I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4  Birthday present // 5.0 // 14 April 2014 // By...
#
#                                              sellers product_state_in_stock  \
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...                    new
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...                      0
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...                    new
# 3                                            unknown                      0
# 4                                            unknown                      0
#
#    Category                 Sub_category_1   Sub_category_2 Sub_category_3  \
# 0  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 1  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 2  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 3  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 4  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
#
#   Sub_category_4
# 0        unknown
# 1        unknown
# 2        unknown
# 3        unknown
# 4        unknown

# %%
df2 = df[['uniq_id', 'customer_reviews']]
df2.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                     customer_reviews
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3  I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4  Birthday present // 5.0 // 14 April 2014 // By...

# %%
def process_review(reviews):
    title, rating, date, reviewer_name, review_content = [], [], [], [], []
    if reviews == 'unknown':
        return reviews
    else:
        reviews = reviews.replace("\n", "")
        reviews = reviews.split("|")
        for review in reviews:
            review = review.split("//")
            # Kiểm tra số lượng phần tử sau khi tách
            if len(review) < 5:
                continue  # Bỏ qua nếu không đủ trường
            try:
                title.append(review[0].strip())
                rating.append(float(review[1].strip()))
                date.append(review[2].strip())
                reviewer_name.append(' '.join(review[3].strip().split('on')[0].strip().split()))
                review_content.append(review[4].strip())
            except (ValueError, IndexError) as e:
                # Gán giá trị mặc định nếu gặp lỗi
                title.append(None)
                rating.append(None)
                date.append(None)
                reviewer_name.append(None)
                review_content.append(None)
        return title, rating, date, reviewer_name, review_content

# %%
process_review(df.customer_reviews[3])
# Out:
# (['I love it'],
#  [5.0],
#  ['22 July 2013'],
#  ['By Lilla Lukacs'],
#  ["I love it. Perfect with the earlier ordered locomotive.Again: I would recommend it to the masters of the topic. It's not just a toy."])

# %%
processed_reviews = df2['customer_reviews'].apply(lambda x: process_review(x))
processed_reviews.head(30)[29]
# Out:
# (['Five Stars', 'Good.', 'Four Stars', 'Five Stars', 'Five Stars'],
#  [5.0, 5.0, 4.0, 5.0, 5.0],
#  ['28 Sept. 2015',
#   '31 Oct. 2015',
#   '22 Dec. 2015',
#   '11 Jan. 2016',
#   '23 Jan. 2016'],
#  ['By philip mantle',
#   'By Skin Inker',
#   'By Edward.F.Gould',
#   'By Mr E Wetherell',
#   'By Mr. P. Newman'],
#  ['it was as advertised ,and delivered promptly',
#   'Easy to wire, looks great on the layout.',
#   'Very satisfied thank you',
#   'thank you /',
#   'Lol'])

# %%
new_data = {
    'uniq_id': [],
    'title': [],
    'rating': [],
    'date': [],
    'reviewer_name': [],
    'review_content': []
}
for idx, review in enumerate(processed_reviews):
    if len(review) != 5:
        print(f"Invalid review format at index {idx}: {review}")
        continue

    titles, ratings, dates, reviewer_names, review_contents = review

    min_length = min(len(titles), len(ratings), len(dates), len(reviewer_names), len(review_contents))
    if min_length == 0:
        print(f"No valid reviews at index {idx}")
        continue

    for i in range(min_length):
        new_data['uniq_id'].append(df['uniq_id'][idx])
        new_data['title'].append(titles[i])
        new_data['rating'].append(ratings[i])
        new_data['date'].append(dates[i])
        new_data['reviewer_name'].append(reviewer_names[i])
        new_data['review_content'].append(review_contents[i])

df_processed = pd.DataFrame(new_data)
# Out:
# Invalid review format at index 71: unknown
# Invalid review format at index 224: unknown
# Invalid review format at index 435: unknown
# Invalid review format at index 554: unknown
# Invalid review format at index 610: unknown
# Invalid review format at index 1012: unknown
# Invalid review format at index 2273: unknown
# Invalid review format at index 2289: unknown
# Invalid review format at index 3020: unknown
# Invalid review format at index 3299: unknown
# Invalid review format at index 3434: unknown
# Invalid review format at index 3606: unknown
# Invalid review format at index 4085: unknown
# Invalid review format at index 4094: unknown
# Invalid review format at index 6402: unknown
# Invalid review format at index 6452: unknown
# No valid reviews at index 7086
# Invalid review format at index 7133: unknown
# Invalid review format at index 7866: unknown
# Invalid review format at index 8923: unknown
# Invalid review format at index 8954: unknown
# Invalid review format at index 9833: unknown

# %%
df_processed.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  eac7efa5dbd3d667f26eb3d3ab504464
# 2  eac7efa5dbd3d667f26eb3d3ab504464
# 3  eac7efa5dbd3d667f26eb3d3ab504464
# 4  eac7efa5dbd3d667f26eb3d3ab504464
#
#                                                title  rating           date  \
# 0      Worth Buying For The Pictures Alone (As Ever)     4.0   6 April 2014
# 1               Amazing detail fabulous photography.     5.0  11 April 2015
# 2                                   'Great Purchase'     5.0  23 April 2014
# 3                                    Great Catalogue     5.0   11 Jun. 2014
# 4  I collect them all as the glossy pictures are ...     5.0    7 Dec. 2014
#
#        reviewer_name                                     review_content
# 0     By Copnovelist  Part of the magic for me growing up as a boy w...
# 1         By richard  Amazing detail, every credit to the photograph...
# 2     By Pinkhandbag  This was purchased on behalf of my Dad. He is ...
# 3  By Gary John Maps  Everything I really needed to see what was on ...
# 4     By David Baker  I collect them all as the glossy pictures are ...

# %%
df_processed[df_processed.isna()== True].head()
# Out:
#   uniq_id title  rating date reviewer_name review_content
# 0     NaN   NaN     NaN  NaN           NaN            NaN
# 1     NaN   NaN     NaN  NaN           NaN            NaN
# 2     NaN   NaN     NaN  NaN           NaN            NaN
# 3     NaN   NaN     NaN  NaN           NaN            NaN
# 4     NaN   NaN     NaN  NaN           NaN            NaN

# %%
df_processed.dropna(inplace = True)

# %%
df_processed.isna().sum()
# Out:
# uniq_id           0
# title             0
# rating            0
# date              0
# reviewer_name     0
# review_content    0
# dtype: int64

# %%
df_processed.to_csv('/content/drive/MyDrive/Course DA/Final Project/customer_review.csv', index = False)

# %%
df_processed = pd.read_csv('/content/drive/MyDrive/Course DA/Final Project/customer_review.csv')
df_processed.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  eac7efa5dbd3d667f26eb3d3ab504464
# 2  eac7efa5dbd3d667f26eb3d3ab504464
# 3  eac7efa5dbd3d667f26eb3d3ab504464
# 4  eac7efa5dbd3d667f26eb3d3ab504464
#
#                                                title  rating           date  \
# 0      Worth Buying For The Pictures Alone (As Ever)     4.0   6 April 2014
# 1               Amazing detail fabulous photography.     5.0  11 April 2015
# 2                                   'Great Purchase'     5.0  23 April 2014
# 3                                    Great Catalogue     5.0   11 Jun. 2014
# 4  I collect them all as the glossy pictures are ...     5.0    7 Dec. 2014
#
#        reviewer_name                                     review_content  year
# 0     By Copnovelist  Part of the magic for me growing up as a boy w...  2014
# 1         By richard  Amazing detail, every credit to the photograph...  2015
# 2     By Pinkhandbag  This was purchased on behalf of my Dad. He is ...  2014
# 3  By Gary John Maps  Everything I really needed to see what was on ...  2014
# 4     By David Baker  I collect them all as the glossy pictures are ...  2014

# %% [markdown]
# ### Tạo bản seller từ sellers ở normalized_data

# %%
df = pd.read_csv("/content/drive/MyDrive/Course DA/Final Project/mormalized_data.csv")
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer  price  \
# 0                              Hornby 2014 Catalogue       Hornby   3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  32.19
#
#    number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                          5                15                           1.0
# 1                          0                 2                           1.0
# 2                          2                17                           2.0
# 3                          0                 1                           2.0
# 4                          0                 3                           2.0
#
#    average_review_rating         customers_who_bought_this_item_also_bought  \
# 0                    4.9  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1                    4.5  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2                    3.9  http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                    5.0                                            unknown
# 4                    4.7  http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
#
#                                          description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
# 1  Technical Details Manufacturer recommended age...
# 2  Technical Details Manufacturer recommended age...
# 3  Technical Details Item Weight259 g Product Dim...
# 4  Technical Details Item Weight159 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                            unknown
# 4  http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
# 1  can you turn off sounds // hi no you cant turn...
# 2  What is the gauge of the track // Hi Paul.Trut...
# 3                                            unknown
# 4                                            unknown
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3  I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4  Birthday present // 5.0 // 14 April 2014 // By...
#
#                                              sellers product_state_in_stock  \
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...                    new
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...                      0
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...                    new
# 3                                            unknown                      0
# 4                                            unknown                      0
#
#    Category                 Sub_category_1   Sub_category_2 Sub_category_3  \
# 0  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 1  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 2  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 3  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 4  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
#
#   Sub_category_4
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df3 = df[['uniq_id', 'sellers']]
df3.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                              sellers
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...
# 3                                            unknown
# 4                                            unknown

# %%
def process_sellers(data):
    data = data.replace("=>", ":")

    if(data == 'unknown'):
      return data
    else:
      try:
        data_dict = ast.literal_eval(data)
      except Exception as e:
        print(f"Error parsing data: {data}")
        return []

      seller_data = []
      sellers = data_dict.get("seller", None)

      if isinstance(sellers, dict):
          seller_name = list(sellers.values())[0]
          seller_price = list(sellers.values())[1]
          seller_data.append({"seller_name": seller_name, "seller_price": seller_price})

      elif isinstance(sellers, list):
          for seller in sellers:
              for key, value in seller.items():
                  if "Seller_name" in key:
                      seller_name = value
                  elif "Seller_price" in key:
                      seller_price = value
              seller_data.append({"seller_name": seller_name, "seller_price": seller_price})
      return seller_data

# %%
process_sellers(df3['sellers'][1])
# Out:
# [{'seller_name': 'UHD WHOLESALE', 'seller_price': '£16.99'}]

# %%
df3['sellers_2'] = df3['sellers'].apply(lambda x: process_sellers(x))
# Out:
# <ipython-input-65-240bb2b17e70>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['sellers_2'] = df3['sellers'].apply(lambda x: process_sellers(x))

# %%
df3['sellers_2'][0]
# Out:
# [{'seller_name': 'Amazon.co.uk', 'seller_price': '£3.42'},
#  {'seller_name': '**stop-&-shop-uk**', 'seller_price': '£0.19'},
#  {'seller_name': 'World Wide Shopping Mall Ltd', 'seller_price': '£9.99'},
#  {'seller_name': 'MyHobbyStore Retail', 'seller_price': '£8.00'},
#  {'seller_name': 'francejouet', 'seller_price': '£37.62'}]

# %%
new_data = {
    'uniq_id': [],
    'seller_name': [],
    'seller_price': []
}

for idx, sellers in enumerate(df3['sellers_2']):
    if sellers == 'unknown':
      continue
    else:
      for seller in sellers:
        new_data['uniq_id'].append(df3['uniq_id'][idx])
        new_data['seller_name'].append(seller['seller_name'])
        new_data['seller_price'].append(seller['seller_price'])

df_processed = pd.DataFrame(new_data)
df_processed.head()
# Out:
#                             uniq_id                   seller_name seller_price
# 0  eac7efa5dbd3d667f26eb3d3ab504464                  Amazon.co.uk        £3.42
# 1  eac7efa5dbd3d667f26eb3d3ab504464            **stop-&-shop-uk**        £0.19
# 2  eac7efa5dbd3d667f26eb3d3ab504464  World Wide Shopping Mall Ltd        £9.99
# 3  eac7efa5dbd3d667f26eb3d3ab504464           MyHobbyStore Retail        £8.00
# 4  eac7efa5dbd3d667f26eb3d3ab504464                   francejouet       £37.62

# %%
df_processed['seller_price'] = df_processed['seller_price'].str.replace('£', '')
df_processed['seller_price'] = df_processed['seller_price'].str.replace(',', '')
df_processed['seller_price'] = df_processed['seller_price'].astype(float)

# %%
df_processed.to_csv('/content/drive/MyDrive/Course DA/Final Project/seller.csv', index = False)

# %% [markdown]
# ## Bước 2: Phân tích thăm dò

# %% [markdown]
# ### Phân tích từng cột

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Course DA/Final Project/Final/data/mormalized_data.csv")
customer_review = pd.read_csv('/content/drive/MyDrive/Course DA/Final Project/Final/data/customer_review.csv')
seller = pd.read_csv('/content/drive/MyDrive/Course DA/Final Project/Final/data/seller.csv')
df_merge = df.merge(customer_review, on = 'uniq_id', how = 'left') \
  .merge(seller, on = 'uniq_id', how = 'left')

# %%
# !pip install ydata-profiling==4.12.1
# Out:
# Collecting ydata-profiling==4.12.1
#   Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl.metadata (20 kB)
# Collecting scipy<1.14,>=1.4.1 (from ydata-profiling==4.12.1)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling==4.12.1) (2.2.2)
# Collecting matplotlib<3.10,>=3.5 (from ydata-profiling==4.12.1)
#   Downloading matplotlib-3.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling==4.12.1) (2.11.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling==4.12.1) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling==4.12.1) (3.1.6)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1)
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling==4.12.1) (2.0.2)
# Collecting htmlmin==0.1.12 (from ydata-profiling==4.12.1)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling==4.12.1)
#   Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling==4.12.1) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling==4.12.1) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling==4.12.1) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling==4.12.1)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling==4.12.1) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling==4.12.1) (4.4.2)
# Collecting imagehash==4.3.1 (from ydata-profiling==4.12.1)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: wordcloud>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling==4.12.1) (1.9.4)
# Collecting dacite>=1.8 (from ydata-profiling==4.12.1)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<1,>=0.56.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling==4.12.1) (0.60.0)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling==4.12.1)
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata-profiling==4.12.1) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==4.12.1) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba<1,>=0.56.0->ydata-profiling==4.12.1) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling==4.12.1) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling==4.12.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling==4.12.1) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling==4.12.1) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling==4.12.1) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2025.1.31)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling==4.12.1) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.11/dist-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1) (3.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.17.0)
# Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 10.5 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 23.1 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading matplotlib-3.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 93.2 MB/s eta 0:00:00
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (687 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 42.9 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 33.3 MB/s eta 0:00:00
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 9.8 MB/s eta 0:00:00
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 107.9 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=67e8253fee3e267ff03d264ab663ea9e1ceeead069ef5da5f12ba184e4585a90
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# Installing collected packages: htmlmin, scipy, PyWavelets, multimethod, dacite, matplotlib, imagehash, visions, phik, ydata-profiling
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
# Successfully installed PyWavelets-1.8.0 dacite-1.9.2 htmlmin-0.1.12 imagehash-4.3.1 matplotlib-3.9.4 multimethod-1.12 phik-0.12.4 scipy-1.13.1 visions-0.7.6 ydata-profiling-4.12.1

# %%
df.isna().sum()
# Out:
# uniq_id                                        0
# product_name                                   0
# manufacturer                                   0
# price                                          0
# number_available_in_stock                      0
# number_of_reviews                              0
# number_of_answered_questions                   0
# average_review_rating                          0
# customers_who_bought_this_item_also_bought     0
# product_information                            0
# product_description                            0
# items_customers_buy_after_viewing_this_item    0
# customer_questions_and_answers                 0
# customer_reviews                               0
# sellers                                        0
# product_state_in_stock                         0
# Category                                       0
# Sub_category_1                                 0
# Sub_category_2                                 0
# Sub_category_3                                 0
# Sub_category_4                                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['uniq_id', 'product_name', 'manufacturer', 'price',
#        'number_available_in_stock', 'number_of_reviews',
#        'number_of_answered_questions', 'average_review_rating',
#        'customers_who_bought_this_item_also_bought', 'product_information',
#        'product_description', 'items_customers_buy_after_viewing_this_item',
#        'customer_questions_and_answers', 'customer_reviews', 'sellers',
#        'product_state_in_stock', 'Category', 'Sub_category_1',
#        'Sub_category_2', 'Sub_category_3', 'Sub_category_4'],
#       dtype='object')

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df_merge, title="Pandas Profiling Report")
profile.to_file(
    "/content/drive/MyDrive/Course DA/Final Project/univariate_profilling.html"
)
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Phân tích theo từ cặp cột

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Course DA/Final Project/Daft/data/mormalized_data.csv")
customer_review = pd.read_csv('/content/drive/MyDrive/Course DA/Final Project/Daft/data/customer_review.csv')
seller = pd.read_csv('/content/drive/MyDrive/Course DA/Final Project/Daft/data/seller.csv')

# %%
df2 = df.groupby('Category')['product_name'].count().reset_index().sort_values(by='product_name', ascending=False)[1:6]

plt.figure(figsize=(8, 6))
plt.bar(df2.head()['Category'], df2.head()['product_name'], edgecolor='black')
plt.title('Top 5 Category with Highest product quantity', fontsize=14)
plt.xlabel('Category', fontsize=12)
plt.ylabel('product quantity', fontsize=12)
plt.xticks(rotation = 45,fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df2 = df.groupby('Category')['price'].mean().reset_index().sort_values(by='price', ascending=False)[1:6]

plt.figure(figsize=(8, 6))
plt.bar(df2.head()['Category'], df2.head()['price'], edgecolor='black')
plt.title('Top 5 Category with Highest price', fontsize=14)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(rotation = 45, fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df2 = df.groupby('product_name')['number_of_reviews'].mean().reset_index()
top_5_products = df2.sort_values(by='number_of_reviews', ascending=False)[1:6]

plt.figure(figsize=(8, 10))

bars = plt.bar(top_5_products['product_name'], top_5_products['number_of_reviews'], edgecolor='black')


plt.title('Top 5 Products with Highest Number Of Reviews', fontsize=14)
plt.xlabel('Product Name', fontsize=10)
plt.ylabel('Average Number of Reviews', fontsize=10)

plt.xticks(ticks=range(len(top_5_products)), labels=top_5_products['product_name'], rotation=45, ha='right', fontsize=10)


plt.grid(axis='y', linestyle='--', alpha=0.25)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.regplot(x='price', y='number_available_in_stock', data=df, scatter_kws={'alpha':0.7})
plt.title('Relationship between Price and Number Available in Stock', fontsize=14)
plt.xlabel('Price', fontsize=12)
plt.ylabel('Number Available in Stock', fontsize=12)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer  price  \
# 0                              Hornby 2014 Catalogue       Hornby   3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  32.19
#
#    number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                          5                15                           1.0
# 1                          0                 2                           1.0
# 2                          2                17                           2.0
# 3                          0                 1                           2.0
# 4                          0                 3                           2.0
#
#    average_review_rating         customers_who_bought_this_item_also_bought  \
# 0                    4.9  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1                    4.5  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2                    3.9  http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                    5.0                                            unknown
# 4                    4.7  http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
# 1  Technical Details Manufacturer recommended age...
# 2  Technical Details Manufacturer recommended age...
# 3  Technical Details Item Weight259 g Product Dim...
# 4  Technical Details Item Weight159 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                            unknown
# 4  http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
# 1  can you turn off sounds // hi no you cant turn...
# 2  What is the gauge of the track // Hi Paul.Trut...
# 3                                            unknown
# 4                                            unknown
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3  I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4  Birthday present // 5.0 // 14 April 2014 // By...
#
#                                              sellers product_state_in_stock  \
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...                    new
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...                      0
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...                    new
# 3                                            unknown                      0
# 4                                            unknown                      0
#
#    Category                 Sub_category_1   Sub_category_2 Sub_category_3  \
# 0  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 1  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 2  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 3  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 4  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
#
#   Sub_category_4
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %% [markdown]
# #### Nhóm chỉ số về tương tác và hành vi người mua

# %%
# Cross sell count
count_no_followup = df['customers_who_bought_this_item_also_bought'][df['customers_who_bought_this_item_also_bought'] == 'unknown'].shape[0]
count_followup = df['customers_who_bought_this_item_also_bought'][df['customers_who_bought_this_item_also_bought'] != 'unknown'].shape[0]

plt.figure(figsize=(8, 10))

labels = ['Buy', 'No buy']
values = [count_followup, count_no_followup]

plt.figure(figsize=(6, 4))
bars = plt.bar(labels, values, color=['#1f77b4', '#ff7f0e'])
plt.title('Count the number of customers who continue to purchase after buying the product.')
plt.ylabel('Total Customer')

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height*1.01,
        f'{height}',
        ha='center',
        va='bottom'
    )

plt.ylim(0, max(values)*1.1)
plt.show()

# %% [markdown]
# Nhận xét:
# - Sau khi mua một sp thì khách hàng có xu hướng mua thêm một sản phẩm khác cao hơn nhiều lần so với không mua nữa.
# - Tỉ lệ cross sell khá lớn => Sản phẩm có nhiều liên kết vs sp khác.

# %%
# Next Product Rate (NPR)
count_no_followup = df['items_customers_buy_after_viewing_this_item'][df['items_customers_buy_after_viewing_this_item'] == 'unknown'].shape[0]
count_followup = df['items_customers_buy_after_viewing_this_item'][df['items_customers_buy_after_viewing_this_item'] != 'unknown'].shape[0]

plt.figure(figsize=(8, 10))

labels = ['Buy', 'No buy']
values = [count_followup, count_no_followup]

plt.figure(figsize=(6, 4))
bars = plt.bar(labels, values, color=['#1f77b4', '#ff7f0e'])
plt.title('Items Customers Buy After Viewing This Item')
plt.ylabel('Total Customer')

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height*1.01,
        f'{height}',
        ha='center',
        va='bottom'
    )

plt.ylim(0, max(values)*1.1)
plt.show()

# %% [markdown]
# Nhận xét:
# - Tỉ lệ chuyển sang sản phẩm khác gấp hai lần so với không mua sp khác => Khách hàng đa số bị hấp dẫn bởi những sản phẩm có liên quan.
# - Khách hàng có xu hướng xem xét, lựa chọn so sánh các sản phẩm kĩ càng.

# %% [markdown]
# #### Chỉ số về trạng thái kho và giá

# %%
#Mức độ sẵn sàng hàng (Availability Index)
no_avai = df['number_available_in_stock'][df['number_available_in_stock'] == 0].shape[0]
avai = df['number_available_in_stock'][df['number_available_in_stock'] != 0].shape[0]

print("In-stock rate = ", avai / (no_avai + avai) * 100, "%")
print("Average Stock = ", np.sum(df['number_available_in_stock']) / (df['product_name'].nunique()))
print('-----------------------------------------------------------------------')

labels = ['available', 'out of stock']
values = [avai, no_avai]

plt.figure(figsize=(6, 4))
bars = plt.bar(labels, values, color=['#1f77b4', '#ff7f0e'])
plt.title('The distribution of Availability Index')
plt.ylabel('count')

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height*1.01,
        f'{height}',
        ha='center',
        va='bottom'
    )

plt.ylim(0, max(values)*1.1)
plt.show()
# Out:
# In-stock rate =  75.0 %
# Average Stock =  5.95915295062224
# -----------------------------------------------------------------------

# %% [markdown]
# Nhận xét:
# - 75% sản phẩm còn hàng trong kho.
# - Trung bình cứ 1 sản phẩm thì còn 6 mặt hàng.

# %%
avg_price_by_category = round(df[df['Category'] != 'unknown']['price'].mean())
avg_price_by_Sub_category_1 = round(df[df['Sub_category_1'] != 'unknown']['price'].mean())
avg_price_by_Sub_category_2 = round(df[df['Sub_category_2'] != 'unknown']['price'].mean())
avg_price_by_Sub_category_3 = round(df[df['Sub_category_3'] != 'unknown']['price'].mean())
avg_price_by_Sub_category_4 = round(df[df['Sub_category_4'] != 'unknown']['price'].mean())

labels = ['category', 'Subcategory 1', 'Subcategory 2', 'Subcategory 3', 'Subcategory 4']
values = [avg_price_by_category, avg_price_by_Sub_category_1, avg_price_by_Sub_category_2, avg_price_by_Sub_category_3, avg_price_by_Sub_category_4]
color_list = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']

plt.figure(figsize=(8, 6))
bars = plt.bar(labels, values, color = color_list)
plt.title('The avarage price of category')
plt.ylabel('price')

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height*1.01,
        f'{height}',
        ha='center',
        va='bottom'
    )

plt.ylim(0, max(values)*1.1)
plt.show()

# %% [markdown]
# #### Chỉ số về người bán (Sellers)

# %%
seller.head()
# Out:
#                             uniq_id                   seller_name  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464                  Amazon.co.uk
# 1  eac7efa5dbd3d667f26eb3d3ab504464            **stop-&-shop-uk**
# 2  eac7efa5dbd3d667f26eb3d3ab504464  World Wide Shopping Mall Ltd
# 3  eac7efa5dbd3d667f26eb3d3ab504464           MyHobbyStore Retail
# 4  eac7efa5dbd3d667f26eb3d3ab504464                   francejouet
#
#    seller_price
# 0          3.42
# 1          0.19
# 2          9.99
# 3          8.00
# 4         37.62

# %%
seller_metrics = seller.groupby('uniq_id').agg(
    Number_of_Sellers=('seller_name', 'nunique'),
    Min_Price=('seller_price', 'min'),
    Max_Price=('seller_price', 'max'),
    Average_Price=('seller_price', 'mean')
).reset_index()

seller_metrics['Price_Range'] = seller_metrics['Max_Price'] - seller_metrics['Min_Price']
seller_metrics.head()
# Out:
#                             uniq_id  Number_of_Sellers  Min_Price  Max_Price  \
# 0  0016eb63fa6c7a5e8930bc7732b13116                 10      48.98     106.00
# 1  00182f9b6081e58fea1fe76bc13eb022                  3      19.99      24.99
# 2  0030f5965cbd07a138147425b9a0156c                  3       6.53      14.99
# 3  0034d77b68130bba71aca6e733c7e1ac                  3      30.23     148.69
# 4  0039295c7fcefba10d5fc333eff806d3                 10     153.63     216.64
#
#    Average_Price  Price_Range
# 0      67.519000        57.02
# 1      22.506667         5.00
# 2       9.373333         8.46
# 3      92.970000       118.46
# 4     199.337000        63.01

# %%
seller_metrics.to_csv("/content/drive/MyDrive/Course DA/Final Project/seller_metrics.csv", index = False)

# %%
seller_metrics['Number_of_Sellers'].value_counts()
# Out:
# Number_of_Sellers
# 1     1927
# 10    1383
# 2      932
# 3      739
# 4      551
# 5      433
# 6      314
# 7      273
# 8      210
# 9      156
# Name: count, dtype: int64

# %%
counts = seller_metrics['Number_of_Sellers'].value_counts()
plt.figure(figsize=(7, 5))
plt.bar(counts.index, counts.values)

plt.title('The distribution of "Number_of_Sellers" per product')
plt.xlabel('Number_of_Sellers')
plt.ylabel('count')

plt.xticks(counts.index)

# Hiển thị
plt.show()

# %%
print('Average Seller Count (ASC): ', round(sum(seller_metrics['Number_of_Sellers']) / seller_metrics['uniq_id'].nunique()))
# Out:
# Average Seller Count (ASC):  4

# %% [markdown]
# Nhận xét:
# - Số sản phẩm được bán độc quyền là cao nhất và giảm dần theo số lượng người bán. Nhưng số lượng sản phẩm có 10 người cạnh tranh nhau đứng thứ 2.
# => Thị trường bán sản phẩm có mức cạnh tranh trung bình cứ 1 sản phẩm sẽ có 4 người bán.

# %% [markdown]
# #### Chỉ số về đánh giá của khách hàng

# %%
customer_review.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  eac7efa5dbd3d667f26eb3d3ab504464
# 2  eac7efa5dbd3d667f26eb3d3ab504464
# 3  eac7efa5dbd3d667f26eb3d3ab504464
# 4  eac7efa5dbd3d667f26eb3d3ab504464
#
#                                                title  rating           date  \
# 0      Worth Buying For The Pictures Alone (As Ever)     4.0   6 April 2014
# 1               Amazing detail fabulous photography.     5.0  11 April 2015
# 2                                   'Great Purchase'     5.0  23 April 2014
# 3                                    Great Catalogue     5.0   11 Jun. 2014
# 4  I collect them all as the glossy pictures are ...     5.0    7 Dec. 2014
#
#        reviewer_name                                     review_content
# 0     By Copnovelist  Part of the magic for me growing up as a boy w...
# 1         By richard  Amazing detail, every credit to the photograph...
# 2     By Pinkhandbag  This was purchased on behalf of my Dad. He is ...
# 3  By Gary John Maps  Everything I really needed to see what was on ...
# 4     By David Baker  I collect them all as the glossy pictures are ...

# %%
counts = customer_review['rating'].value_counts()
plt.figure(figsize=(7, 5))
plt.bar(counts.index, counts.values)

plt.title('The distribution of rating')
plt.xlabel('rating')
plt.ylabel('count')

plt.xticks(counts.index)

plt.show()

# %% [markdown]
# Nhận xét:
# - Đa số khách hàng hài lòng với chất lượng sản phẩm (5 sao chiếm đa số)

# %%
#customer_review['date'].replace(".", "", inplace = True)
#customer_review['year'] = customer_review['date'].apply(lambda x: x.split()[-1])

rating_by_month = customer_review.groupby('year')['rating'].mean().reset_index()

plt.plot(rating_by_month['year'].astype(str), rating_by_month['rating'], marker='o')
plt.xticks(rotation=45)
plt.title('Xu hướng rating trung bình theo thời gian')
plt.xlabel('Tháng')
plt.ylabel('Rating trung bình')
plt.show()

# %% [markdown]
# Nhận xét:
# - Rating của toàn bộ sản phẩm bắt đầu từ năm 2001 là xấp xỉ 4.6 và tăng đến mức độ tối đa vào năm 2002.
# - Đạt mức thấp nhất vào năm 2006, khoảng 4.3 sao. Sau đó, duy trì mức ổn định như lúc ban đầu. \
# => Nhìn chung, Amazon có sản phẩm khá tốt, đánh giá theo các năm giao động [4.3, 5.0].

# %%
customer_review['review_content_clean'] = customer_review['review_content'].apply(
    lambda x: re.sub(r'[^a-zA-Z\s]', '', str(x))
)
customer_review['review_content_clean'] = customer_review['review_content_clean'].fillna('')

text = " ".join(customer_review['review_content_clean'])

stopwords = set(STOPWORDS)

wordcloud = WordCloud(
    width=800,
    height=600,
    background_color='white',
    stopwords=stopwords,
    min_font_size=10
).generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud cho review_content", fontsize=16)
plt.show()

# %% [markdown]
# ### Phân tích nhiều cột

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Course DA/Final Project/Final/data/mormalized_data.csv")
customer_review = pd.read_csv('/content/drive/MyDrive/Course DA/Final Project/Final/data/customer_review.csv')
seller = pd.read_csv('/content/drive/MyDrive/Course DA/Final Project/Final/data/seller.csv')

# %%
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer  price  \
# 0                              Hornby 2014 Catalogue       Hornby   3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  32.19
#
#    number_available_in_stock  number_of_reviews  number_of_answered_questions  \
# 0                          5               15.0                           1.0
# 1                          0                2.0                           1.0
# 2                          2               17.0                           2.0
# 3                          0                1.0                           2.0
# 4                          0                3.0                           2.0
#
#    average_review_rating         customers_who_bought_this_item_also_bought  \
# 0                    4.9  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1                    4.5  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2                    3.9  http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                    5.0                                            unknown
# 4                    4.7  http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
#
#                                  product_information  ...  \
# 0  Technical Details Item Weight640 g Product Dim...  ...
# 1  Technical Details Manufacturer recommended age...  ...
# 2  Technical Details Manufacturer recommended age...  ...
# 3  Technical Details Item Weight259 g Product Dim...  ...
# 4  Technical Details Item Weight159 g Product Dim...  ...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                            unknown
# 4  http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
# 1  can you turn off sounds // hi no you cant turn...
# 2  What is the gauge of the track // Hi Paul.Trut...
# 3                                            unknown
# 4                                            unknown
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3  I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4  Birthday present // 5.0 // 14 April 2014 // By...
#
#                                              sellers product_state_in_stock  \
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...                    new
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...                      0
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...                    new
# 3                                            unknown                      0
# 4                                            unknown                      0
#
#    Category                 Sub_category_1   Sub_category_2 Sub_category_3  \
# 0  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 1  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 2  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 3  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
# 4  Hobbies    Model Trains & Railway Sets    Rail Vehicles          Trains
#
#   Sub_category_4
# 0        unknown
# 1        unknown
# 2        unknown
# 3        unknown
# 4        unknown
#
# [5 rows x 21 columns]

# %%
customer_review.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  eac7efa5dbd3d667f26eb3d3ab504464
# 2  eac7efa5dbd3d667f26eb3d3ab504464
# 3  eac7efa5dbd3d667f26eb3d3ab504464
# 4  eac7efa5dbd3d667f26eb3d3ab504464
#
#                                           title  rating           date  \
# 0              Worth Buying Pictures Alone Ever     4.0   6 April 2014
# 1           Amazing detail fabulous photography     5.0  11 April 2015
# 2                                Great Purchase     5.0  23 April 2014
# 3                               Great Catalogue     5.0   11 Jun. 2014
# 4  collect glossy pictures great nice still get     5.0    7 Dec. 2014
#
#        reviewer_name                                     review_content  year  \
# 0     By Copnovelist  Part of the magic for me growing up as a boy w...  2014
# 1         By richard  Amazing detail, every credit to the photograph...  2015
# 2     By Pinkhandbag  This was purchased on behalf of my Dad. He is ...  2014
# 3  By Gary John Maps  Everything I really needed to see what was on ...  2014
# 4     By David Baker  I collect them all as the glossy pictures are ...  2014
#
#                                 review_content_clean
# 0  Part magic growing boy buy given new Hornby ca...
# 1  Amazing detail every credit photographer book ...
# 2  purchased behalf Dad always asking look 00 gau...
# 3  Everything really needed see offer Hornby way ...
# 4  collect glossy pictures great nice still get c...

# %%
seller.head()
# Out:
#                             uniq_id                   seller_name  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464                  Amazon.co.uk
# 1  eac7efa5dbd3d667f26eb3d3ab504464            **stop-&-shop-uk**
# 2  eac7efa5dbd3d667f26eb3d3ab504464  World Wide Shopping Mall Ltd
# 3  eac7efa5dbd3d667f26eb3d3ab504464           MyHobbyStore Retail
# 4  eac7efa5dbd3d667f26eb3d3ab504464                   francejouet
#
#    seller_price
# 0          3.42
# 1          0.19
# 2          9.99
# 3          8.00
# 4         37.62

# %%
df_merge = df.merge(customer_review, on = 'uniq_id', how = 'left') \
  .merge(seller, on = 'uniq_id', how = 'left')

# %%
numeric_columns = ['price', 'number_available_in_stock', 'number_of_reviews',
                   'average_review_rating']

df_numeric = df_merge[numeric_columns].apply(pd.to_numeric, errors='coerce')

corr_matrix = df_numeric.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Heat map")
plt.show()

# %%
sns.pairplot(df[numeric_columns])
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.boxplot(x='Category', y='price', data=df)
plt.title('Phân phối giá theo Category')
plt.xticks(rotation=30, ha='right', fontsize=10)
plt.show()

# %%
df_merge['price_difference'] = df_merge['seller_price'] - df['price']
df_merge['percent_difference'] = (df_merge['price_difference'] / df_merge['price']) * 100

plt.figure(figsize=(10, 6))
sns.histplot(df_merge['percent_difference'], bins=10, kde=True, color='#1f77b4')
plt.title("Percentage distribution of the price difference between seller_price and price")
plt.xlabel("Percentage difference (%)")
plt.ylabel("Number of transaction")
plt.show()

# %% [markdown]
# Nhận xét: Nếu phần trăm chênh lệch có giá trị âm: Người bán đang bán với giá thấp hơn giá niêm yết, có thể cho thấy cạnh tranh về giá, khuyến khích khách hàng mua bằng giá ưu đãi.
